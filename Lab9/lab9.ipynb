# %% [markdown]
# Copyright **`(c)`** 2023 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free for personal or classroom use; see [`LICENSE.md`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %% [markdown]
# # LAB9
#
# Write a local-search algorithm (eg. an EA) able to solve the *Problem* instances 1, 2, 5, and 10 on a 1000-loci genomes, using a minimum number of fitness calls. That's all.
#
# ### Deadlines:
#
# * Submission: Sunday, December 3 ([CET](https://www.timeanddate.com/time/zones/cet))
# * Reviews: Sunday, December 10 ([CET](https://www.timeanddate.com/time/zones/cet))
#
# Notes:
#
# * Reviews will be assigned  on Monday, December 4
# * You need to commit in order to be selected as a reviewer (ie. better to commit an empty work than not to commit)

# %%
from random import choices, random, randint
from queue import PriorityQueue
import numpy as np
# %pip install sortedcontainers
from sortedcontainers import SortedList

import lab9_lib
# Out:
# Requirement already satisfied: sortedcontainers in c:\users\vicin\desktop\polito\compint\venv\lib\site-packages (2.4.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# # Utils

# %%
def print_ind(ind):
    return f"{''.join(str(g) for g in ind)}"

def _mutate(a, prob: float):
    if random()<prob:
        return 1-a
    else:
        return a
    
def _mutation_mask(a,b):
    if a!=b:
        return b
    else:
        return -1
    
def _reapply_mutation(a,b):
    if a==-1:
        return b
    else:
        return a
    
def _crossover(a, b):
    if random()>0.5:
        return a
    else:
        return b
    
def gen_population(start_population:int, fitness:callable):
    population=SortedList(key=lambda e: -e[0])
    for i in range(start_population):
        ind=choices([0, 1], k=1000)
        fit=fitness(ind)
        population.add([fit,ind])
    return population

def print_population(population, verbose: bool):
    if not verbose:
        return
    for i in population:
        print(f"{i[0]:.2%} {print_ind(i[1])}")
    
gene_prob=[0 for _ in range(1000)]
special_mut=0

mutate=np.vectorize(_mutate)
mutation_mask=np.vectorize(_mutation_mask)
reapply_mutation=np.vectorize(_reapply_mutation)
crossover=np.vectorize(_crossover)

# %% [markdown]
# # Absolute Perfect Solution

# %%
def absolute_perfect_solution():
    return [1 for i in range(0,50)]

# %% [markdown]
# # Just Mutation
#
# Basically kills some individuals, mutate some others (and puts back both the original and the new one) \
# With: \
# Mutation(100, 0.1,0.5,0.1,fitness, verbose=False)
# - Problem 2: 96-100%
# - Problem 5: 75-80%
# - Problem 10: 70-80%

# %%
class Mutation():
    def __init__(self, start_population: int, kill_perc: float, mut_prob: float, gene_mut_prob:float, fitness: callable , with_removal:bool=False, verbose:bool=False, max_population:int=1000):
        self.population=gen_population(start_population, fitness)
        self.mut_prob=mut_prob
        self.gene_mut_prob=gene_mut_prob
        self.kill_perc=kill_perc
        self.epochs=0
        self.verbose=verbose
        self.fitness=fitness
        self.with_removal=with_removal
        self.max_population=max_population
        
        print_population(self.population, self.verbose)

    def step(self):
        global mutate
        
        self.epochs+=1

        ### KILL ###
        kill_population(self.population, self.kill_perc, self.max_population)
        
        ### MUTATE ###
        mutate_population(self.population, self.mut_prob, self.gene_mut_prob, self.fitness, self.with_removal)
                    #print(f"After: {i[0]:.2%} {print_ind(i[1])}")
        print("Epoch: ", self.epochs," individuals: ", len(self.population), " best fitness: ", self.best[0])
        #print(print_ind(self.best[1]))
        print_population(self.population, self.verbose)
    
    @property
    def best(self):
        return self.population[0]
    
def kill_population(population:list, kill_perc:float, max_pop=None):
    to_remove=int(len(population)*kill_perc)

    for _ in range(to_remove):
        population.pop()
    if max_pop!=None:
        while(len(population)>max_pop):
            population.pop()
            
        
    
def mutate_population(population,  population_sub:list, mut_prob: float, gene_mut_prob:float, fitness: callable , with_removal:bool=False):
    global gene_prob
    mutations=0
    for i in population_sub:
        #prob=(1 - (i[0]/100)) * mut_prob 
        prob_ind=[0 for _ in range(1000)]
        prob=mut_prob
        if(random()<prob):
            t=mutate(i[1], gene_mut_prob*(1-i[0]))
            t_fit=fitness(t)
            if t_fit>i[0]:
                mask=mutation_mask(i[1], t)
                gene_prob=reapply_mutation(mask, gene_prob)
            if(with_removal):
                population.remove(i)
            population.add([t_fit,t.tolist()])
            mutations+=1

# %% [markdown]
# # Crossover
#
# With random crossover it seems mutation gives better solutions \
#
# With this setting in can reach 100% of fitness in a range o
# cross=Crossover(50, 0.1, 5, .6, .5, fitness, verbose=False, with_removal=True)
# for _ in range(10000):
#     cross.step()

# %%
class Crossover():
    def __init__(self, start_population: int, kill_perc: float, offspring: int, mut_prob: float, gene_mut_prob:float, fitness: callable ,max_population:int=1000, with_removal:bool=False, verbose:bool=False):
        self.population=gen_population(start_population, fitness)
        self.kill_perc=kill_perc
        self.offspring=offspring
        self.mut_prob=mut_prob
        self.gene_mut_prob=gene_mut_prob
        self.fitness=fitness
        self.with_removal=with_removal
        self.verbose=verbose
        self.max_population=max_population
        self.epochs=0

        print_population(self.population, self.verbose)

    def step(self, elite_threshold=0.2, losers_pool=None, max_loser=600):
        global mutate, crossover, loser_population
        
        self.epochs+=1

        
        elite=int(elite_threshold*len(self.population))

        n_couples=int(0.5*elite*0.5)

        

        for _ in range(n_couples):
            crossover_population_by_difference(self.population, self.population, self.offspring, self.fitness)

        
        mutate_population(self.population, self.population, self.mut_prob, self.gene_mut_prob,self.fitness, self.with_removal)
        
        if losers_pool is None:
            kill_population(self.population, self.kill_perc,self.max_population)
        else:
            loser_population(self.population, losers_pool, self.kill_perc,self.max_population, max_loser)

        print("Epoch: ", self.epochs," individuals: ", len(self.population), " best fitness: ", self.best[0], " ",self.population[-1][0])
        #print(print_ind(self.best[1]))
        print_population(self.population, self.verbose)
    @property
    def best(self):
        return self.population[0]
    
    
    
def inject_new_individuals(population:SortedList, fitness, n=5):
    for _ in range(n):
        ind=choices([0, 1], k=1000)
        fit=fitness(ind)
        population.add([fit,ind])
    
def crossover_population(population_sub, population,offspring, fitness):
    #selected=[0 for _ in population]
    #print("Selected len: ", len(selected), " population: ", len(population))

    p1=0
    p2=0
    #while(True):
    p1=randint(0,len(population_sub)-1)
    p2=randint(0,len(population_sub)-1)
        # print("P1: ",p1," P2: ",p2, len(population))
        # if p2!=p1 and (selected[p1]==0) and (selected[p2]==0):
        #     break
    #selected[p1]=1
    #selected[p2]=1

    parent1=population_sub[p1]
    parent2=population_sub[p2]

    for _ in range(offspring):
        ind=crossover(parent1[1],parent2[1]).tolist()
        fit=fitness(ind)
        if ind!= parent1[1] and ind != parent2[1]:
            population.add([fit,ind])

def crossover_population_by_difference(population_sub, population,offspring, fitness):
    #selected=[0 for _ in population]
    #print("Selected len: ", len(selected), " population: ", len(population))

    p1=0
    p2=0
    #while(True):
    p1=randint(0,len(population_sub)-1)
    p2=0
        # print("P1: ",p1," P2: ",p2, len(population))
        # if p2!=p1 and (selected[p1]==0) and (selected[p2]==0):
        #     break
    #selected[p1]=1
    #selected[p2]=1
    parent1=population_sub[p1]
    parent2=population_sub[p2]
    maxent=0
    for i in range(len(population_sub)):
        temp=population_sub[i]
        e=entropy(parent1[1],temp[1])
        
        if e>maxent:
            maxent=e
            parent2=temp

    #print(f"{print_ind(temp[1])}, {e}")

    for _ in range(offspring):
        ind=crossover(parent1[1],parent2[1]).tolist()
        if ind!= parent1[1] and ind != parent2[1]:
            fit=fitness(ind)
            population.add([fit,ind])

def entropy(ind1, ind2):
    return sum([1 for i in range(len(ind1)) if ind1[i]!=ind2[1]])

# %%
def remove_similar(population:SortedList):
    individuals=[]
    for i in population:
        if i in individuals:
            population.remove(i)
        else:
            individuals.append(i)

# %% [markdown]
# # Testing Solution
#
# Crossover + Islands + Mass Extinctions:
# start ind=50
# kill_perc=0.5
# offsprings=15
# mutation_prob= 0.8
# gene_mutation_prob = .5
# with_removal=False
# max_population=200
#
# extermination=0.9 (every 40)
#
# Problem 2: 100% in 1.3M fitness calls
# Problem 5: 100% in 1.5M fitness calls
# Problem 10: 50% in 3M fitness calls

# %%
fitness = lab9_lib.make_problem(10)

#mut=Mutation(100, 0,0.1,.2,fitness, verbose=False, max_population=500)
#for i in range(10000):
#    mut.step()
#    if ((i+1)%40) == 0:
#        inject_new_individuals(cross.population,fitness,30)
# best=mut.best
# print(f"{best[0]:.2%} {print_ind(best[1])}")

losers_pool=SortedList()
cross1=Crossover(50, 0.5, 15, .8, .5, fitness, verbose=False, with_removal=False,max_population=200)
cross2=Crossover(50, 0.5, 15, .8, .5, fitness, verbose=False, with_removal=False,max_population=200)


for i in range(10000):
    cross1.step(.2)
    cross2.step(.2)
    
    # if i%40==0:
    #    if len(losers_pool)>20:
    #        cross1.population.update(losers_pool[:])
    #        cross2.population.update(losers_pool[:])
    #    kill_population(losers_pool, 1,100)
    #    inject_new_individuals(cross2.population,fitness, 30)
    #    inject_new_individuals(cross1.population,fitness, 30)
    #    print(len(losers_pool))
    remove_similar(cross1.population)
    remove_similar(cross2.population)

    

    #mutate_population(losers_pool,losers_pool, 0.8,.5,fitness)
    #kill_population(losers_pool, 0,100)
    #remove_similar(losers_pool)

    # if len(cross1.population)>5 and len(cross2.population)>5:
    #     cross1.population.update(cross2.population[:5])
    #     cross2.population.update(cross1.population[:5])

    if (i+1 )% 40==0:
        kill_population(cross1.population, 0.95,200)
        kill_population(cross2.population, 0.95, 200)
        inject_new_individuals(cross2.population,fitness, 30)
        inject_new_individuals(cross1.population,fitness, 30)
        cross1.population.update(cross2.population[:5])
        cross2.population.update(cross1.population[:5])
    
    print(f"\nCalls {fitness.calls}")
    if cross1.best[0]==1.0 or cross2.best[0]==1.0:
        break


best1=cross1.best
best2=cross2.best


print(f"{best1[0]:.2%} {print_ind(best1[1])}")
print(f"{best2[0]:.2%} {print_ind(best2[1])}")

print(f"\nCalls {fitness.calls}")
# Out:
# Epoch:  1  individuals:  180  best fitness:  0.20255789400000002   0.052022344576
# Epoch:  1  individuals:  134  best fitness:  0.202457828   0.052704691118
#
# Calls 627
# Epoch:  2  individuals:  200  best fitness:  0.210348017   0.10212478017
# Epoch:  2  individuals:  200  best fitness:  0.218345796   0.060348145895999995
#
# Calls 2996
# Epoch:  3  individuals:  200  best fitness:  0.210348017   0.10779112496
# Epoch:  3  individuals:  200  best fitness:  0.21835711900000002   0.10644779032
#
# Calls 6024
# Epoch:  4  individuals:  200  best fitness:  0.26978027   0.11000144684
# Epoch:  4  individuals:  200  best fitness:  0.21835711900000002   0.10992234807
#
# Calls 9328
# Epoch:  5  individuals:  200  best fitness:  0.26978027   0.11225667906
# Epoch:  5  individuals:  200  best fitness:  0.25922806000000004   0.11180245808
#
# Calls 12607
# Epoch:  6  individuals:  200  best fitness:  0.26978027   0.11590245706999999
# Epoch:  6  individuals:  200  best fitness:  0.25922806000000004   0.11381126928
#
# Calls 15821
# Epoch:  7  individuals:  200  best fitness:  0.26978027   0.1532578939
# Epoch:  7  individuals:  200  best fitness:  0.25922806000000004   0.11947234729999999
#
# Calls 20691
# Epoch:  8  individuals:  200  best fitness:  0.26978027   0.15336777950000002
# Epoch:  8  individuals:  200  best fitness:  0.31247   0.1503466784
#
# Calls 23850
# Epoch:  9  individuals:  200  best fitness:  0.41039   0.15612467000000002
# Epoch:  9  individuals:  200  best fitness:  0.31247   0.1532446938
#
# Calls 27044
# Epoch:  10  individuals:  200  best fitness:  0.41039   0.1562557798
# Epoch:  10  individuals:  200  best fitness:  0.31247   0.153557795
#
# Calls 30169
# Epoch:  11  individuals:  200  best fitness:  0.41039   0.1590222686
# Epoch:  11  individuals:  200  best fitness:  0.31247   0.1561356816
#
# Calls 33167
# Epoch:  12  individuals:  200  best fitness:  0.41039   0.159115691
# Epoch:  12  individuals:  200  best fitness:  0.31247   0.1563356852
#
# Calls 36170
# Epoch:  13  individuals:  200  best fitness:  0.41039   0.1592349028
# Epoch:  13  individuals:  200  best fitness:  0.31247   0.1590123504
#
# Calls 39216
# Epoch:  14  individuals:  200  best fitness:  0.41039   0.1618892363
# Epoch:  14  individuals:  200  best fitness:  0.31247   0.1590557805
#
# Calls 42119
# Epoch:  15  individuals:  200  best fitness:  0.41039   0.16193355750000002
# Epoch:  15  individuals:  200  best fitness:  0.31247   0.15913335879999999
#
# Calls 45236
# Epoch:  16  individuals:  200  best fitness:  0.41039   0.16200255730000002
# Epoch:  16  individuals:  200  best fitness:  0.31247   0.15924466839999998
#
# Calls 48264
# Epoch:  17  individuals:  200  best fitness:  0.41039   0.1620356697
# Epoch:  17  individuals:  200  best fitness:  0.31247   0.159469014
#
# Calls 51300
# Epoch:  18  individuals:  200  best fitness:  0.41039   0.16211356100000002
# Epoch:  18  individuals:  200  best fitness:  0.31247   0.1619046913
#
# Calls 54457
# Epoch:  19  individuals:  200  best fitness:  0.41039   0.1621581229
# Epoch:  19  individuals:  200  best fitness:  0.31247   0.1620023794
#
# Calls 57568
# Epoch:  20  individuals:  200  best fitness:  0.41039   0.1622446728
# Epoch:  20  individuals:  200  best fitness:  0.31247   0.1620136708
#
# Calls 60576
# Epoch:  21  individuals:  200  best fitness:  0.41039   0.1624556729
# Epoch:  21  individuals:  200  best fitness:  0.31247   0.16202345980000002
#
# Calls 63569
# Epoch:  22  individuals:  200  best fitness:  0.41039   0.16477924049999998
# Epoch:  22  individuals:  200  best fitness:  0.31247   0.1621266794
#
# Calls 66664
# Epoch:  23  individuals:  200  best fitness:  0.41039   0.1648013695
# Epoch:  23  individuals:  200  best fitness:  0.31247   0.1622356938
#
# Calls 69631
# Epoch:  24  individuals:  200  best fitness:  0.41039   0.1648935583
# Epoch:  24  individuals:  200  best fitness:  0.31247   0.1625679011
#
# Calls 72736
# Epoch:  25  individuals:  200  best fitness:  0.41039   0.1649225783
# Epoch:  25  individuals:  200  best fitness:  0.31247   0.1648014507
#
# Calls 75956
# Epoch:  26  individuals:  200  best fitness:  0.41039   0.1650234577
# Epoch:  26  individuals:  200  best fitness:  0.31247   0.1648033583
#
# Calls 79198
# Epoch:  27  individuals:  200  best fitness:  0.41039   0.1650357783
# Epoch:  27  individuals:  200  best fitness:  0.31247   0.1649013573
#
# Calls 82382
# Epoch:  28  individuals:  200  best fitness:  0.41039   0.16512369100000002
# Epoch:  28  individuals:  200  best fitness:  0.31247   0.1649222613
#
# Calls 85598
# Epoch:  29  individuals:  200  best fitness:  0.41039   0.1651349118
# Epoch:  29  individuals:  200  best fitness:  0.31247   0.1650001583
#
# Calls 88712
# Epoch:  30  individuals:  200  best fitness:  0.41039   0.16522378000000001
# Epoch:  30  individuals:  200  best fitness:  0.31247   0.1651235684
#
# Calls 91837
# Epoch:  31  individuals:  200  best fitness:  0.41039   0.16768058970000002
# Epoch:  31  individuals:  200  best fitness:  0.31247   0.165134569
#
# Calls 94831
# Epoch:  32  individuals:  200  best fitness:  0.41039   0.1677815727
# Epoch:  32  individuals:  200  best fitness:  0.31247   0.1676818041
#
# Calls 97789
# Epoch:  33  individuals:  200  best fitness:  0.41039   0.1678025808
# Epoch:  33  individuals:  200  best fitness:  0.31247   0.16779348970000002
#
# Calls 101028
# Epoch:  34  individuals:  200  best fitness:  0.41039   0.16792456849999998
# Epoch:  34  individuals:  200  best fitness:  0.31247   0.168046795
#
# Calls 104102
# Epoch:  35  individuals:  200  best fitness:  0.41039   0.1680233686
# Epoch:  35  individuals:  200  best fitness:  0.31247   0.1707790374
#
# Calls 106973
# Epoch:  36  individuals:  200  best fitness:  0.41039   0.16823356720000002
# Epoch:  36  individuals:  200  best fitness:  0.31247010000000003   0.17112570170000002
#
# Calls 109949
# Epoch:  37  individuals:  200  best fitness:  0.41039   0.1682337909
# Epoch:  37  individuals:  200  best fitness:  0.31247010000000003   0.17112570170000002
#
# Calls 112789
# Epoch:  38  individuals:  200  best fitness:  0.41039   0.1705758007
# Epoch:  38  individuals:  200  best fitness:  0.31247010000000003   0.190669017
#
# Calls 115812
# Epoch:  39  individuals:  200  best fitness:  0.41039   0.17080357950000002
# Epoch:  39  individuals:  200  best fitness:  0.31247010000000003   0.194577895
#
# Calls 118926
# Epoch:  40  individuals:  200  best fitness:  0.41039   0.17090892400000002
# Epoch:  40  individuals:  200  best fitness:  0.31247010000000003   0.202334579
#
# Calls 122192
# Epoch:  41  individuals:  186  best fitness:  0.41039   0.052022233577999996
# Epoch:  41  individuals:  161  best fitness:  0.41039   0.052703357799999996
#
# Calls 122794
# Epoch:  42  individuals:  200  best fitness:  0.41039   0.10402233794999999
# Epoch:  42  individuals:  200  best fitness:  0.41039   0.10022578906
#
# Calls 125422
# Epoch:  43  individuals:  200  best fitness:  0.41039   0.10790122799
# Epoch:  43  individuals:  200  best fitness:  0.41039   0.10793556817
#
# Calls 128332
# Epoch:  44  individuals:  200  best fitness:  0.41039   0.11013566806
# Epoch:  44  individuals:  200  best fitness:  0.41039   0.1101122235
#
# Calls 131356
# Epoch:  45  individuals:  200  best fitness:  0.41039   0.11202255909
# Epoch:  45  individuals:  200  best fitness:  0.41039   0.11435781128
#
# Calls 134402
# Epoch:  46  individuals:  200  best fitness:  0.41039   0.11813344784999999
# Epoch:  46  individuals:  200  best fitness:  0.41039   0.14756789069999998
#
# Calls 137164
# Epoch:  47  individuals:  200  best fitness:  0.41039   0.1532244574
# Epoch:  47  individuals:  200  best fitness:  0.41039   0.1533779227
#
# Calls 140337
# Epoch:  48  individuals:  200  best fitness:  0.41039   0.1561222263
# Epoch:  48  individuals:  200  best fitness:  0.41039   0.1561245132
#
# Calls 143241
# Epoch:  49  individuals:  200  best fitness:  0.41039   0.1561478912
# Epoch:  49  individuals:  200  best fitness:  0.41039   0.15614445610000002
#
# Calls 146350
# Epoch:  50  individuals:  200  best fitness:  0.41039   0.1564467807
# Epoch:  50  individuals:  200  best fitness:  0.41039   0.1562233485
#
# Calls 149273
# Epoch:  51  individuals:  200  best fitness:  0.41039   0.159122792
# Epoch:  51  individuals:  200  best fitness:  0.41039   0.1563456794
#
# Calls 152450
# Epoch:  52  individuals:  200  best fitness:  0.41039   0.15924777950000002
# Epoch:  52  individuals:  200  best fitness:  0.41039   0.15902353500000002
#
# Calls 155536
# Epoch:  53  individuals:  200  best fitness:  0.41039   0.1619012363
# Epoch:  53  individuals:  200  best fitness:  0.41039   0.1591133649
#
# Calls 158410
# Epoch:  54  individuals:  200  best fitness:  0.41039   0.1619223583
# Epoch:  54  individuals:  200  best fitness:  0.41039   0.1592236795
#
# Calls 161394
# Epoch:  55  individuals:  200  best fitness:  0.41039   0.1620123389
# Epoch:  55  individuals:  200  best fitness:  0.41039   0.16191290190000002
#
# Calls 164266
# Epoch:  56  individuals:  200  best fitness:  0.41039   0.16202445969999998
# Epoch:  56  individuals:  200  best fitness:  0.41039   0.16201347060000001
#
# Calls 167519
# Epoch:  57  individuals:  200  best fitness:  0.41039   0.1621135672
# Epoch:  57  individuals:  200  best fitness:  0.41039   0.1620346795
#
# Calls 170499
# Epoch:  58  individuals:  200  best fitness:  0.41039   0.1622235705
# Epoch:  58  individuals:  200  best fitness:  0.41039   0.16215777979999998
#
# Calls 173377
# Epoch:  59  individuals:  200  best fitness:  0.41039   0.16479334750000002
# Epoch:  59  individuals:  200  best fitness:  0.41039   0.16233469020000002
#
# Calls 176258
# Epoch:  60  individuals:  200  best fitness:  0.41039   0.1648023572
# Epoch:  60  individuals:  200  best fitness:  0.41039   0.16235669
#
# Calls 179210
# Epoch:  61  individuals:  200  best fitness:  0.41039   0.1649247786
# Epoch:  61  individuals:  200  best fitness:  0.41039   0.1649012353
#
# Calls 182172
# Epoch:  62  individuals:  200  best fitness:  0.41039   0.1650014909
# Epoch:  62  individuals:  200  best fitness:  0.41039   0.16490467949999998
#
# Calls 185326
# Epoch:  63  individuals:  200  best fitness:  0.41039   0.16501146049999998
# Epoch:  63  individuals:  200  best fitness:  0.41039   0.1650223576
#
# Calls 188242
# Epoch:  64  individuals:  200  best fitness:  0.41039   0.16504467299999998
# Epoch:  64  individuals:  200  best fitness:  0.41039   0.1650255696
#
# Calls 191083
# Epoch:  65  individuals:  200  best fitness:  0.41039   0.1651346699
# Epoch:  65  individuals:  200  best fitness:  0.41039   0.16513445640000002
#
# Calls 193963
# Epoch:  66  individuals:  200  best fitness:  0.41039   0.1652456914
# Epoch:  66  individuals:  200  best fitness:  0.41039   0.15912566960000002
#
# Calls 196902
# Epoch:  67  individuals:  200  best fitness:  0.41039   0.1678135683
# Epoch:  67  individuals:  200  best fitness:  0.41039   0.1620144907
#
# Calls 199837
# Epoch:  68  individuals:  200  best fitness:  0.41039   0.1648124029
# Epoch:  68  individuals:  200  best fitness:  0.41039   0.1678226119
#
# Calls 202829
# Epoch:  69  individuals:  200  best fitness:  0.41039   0.1648124029
# Epoch:  69  individuals:  200  best fitness:  0.41039   0.1620225797
#
# Calls 205718
# Epoch:  70  individuals:  200  best fitness:  0.41039   0.1680334473
# Epoch:  70  individuals:  200  best fitness:  0.41039   0.1679070121
#
# Calls 208336
# Epoch:  71  individuals:  200  best fitness:  0.41039   0.1622446717
# Epoch:  71  individuals:  200  best fitness:  0.41039   0.16793457950000001
#
# Calls 211204
# Epoch:  72  individuals:  200  best fitness:  0.41039   0.1681144697
# Epoch:  72  individuals:  200  best fitness:  0.41039   0.1683334695
#
# Calls 213927
# Epoch:  73  individuals:  200  best fitness:  0.41039   0.1681224684
# Epoch:  73  individuals:  200  best fitness:  0.41039   0.1650234518
#
# Calls 216570
# Epoch:  74  individuals:  200  best fitness:  0.41039   0.1681334494
# Epoch:  74  individuals:  200  best fitness:  0.41039   0.17092569059999999
#
# Calls 219496
# Epoch:  75  individuals:  200  best fitness:  0.41039   0.1683567896
# Epoch:  75  individuals:  200  best fitness:  0.41039   0.1763794619
#
# Calls 222401
# Epoch:  76  individuals:  200  best fitness:  0.41039   0.1652235594
# Epoch:  76  individuals:  200  best fitness:  0.41039   0.16234668970000002
#
# Calls 225377
# Epoch:  77  individuals:  200  best fitness:  0.41039   0.1652235594
# Epoch:  77  individuals:  200  best fitness:  0.41039   0.198467918
#
# Calls 228351
# Epoch:  78  individuals:  200  best fitness:  0.41039   0.1706000254
# Epoch:  78  individuals:  200  best fitness:  0.41039   0.15934569110000002
#
# Calls 231151
# Epoch:  79  individuals:  200  best fitness:  0.41039   0.1770167939
# Epoch:  79  individuals:  200  best fitness:  0.41039   0.20622359599999998
#
# Calls 233886
# Epoch:  80  individuals:  200  best fitness:  0.41039   0.1654467806
# Epoch:  80  individuals:  200  best fitness:  0.41039   0.206234576
#
# Calls 236824
# Epoch:  81  individuals:  199  best fitness:  0.41039   0.05255856793
# Epoch:  81  individuals:  200  best fitness:  0.41039   0.052906789134
#
# Calls 237549
# Epoch:  82  individuals:  200  best fitness:  0.41039   0.10423457906
# Epoch:  82  individuals:  200  best fitness:  0.41039   0.10403790024
#
# Calls 240431
# Epoch:  83  individuals:  200  best fitness:  0.41039   0.1079002345
# Epoch:  83  individuals:  200  best fitness:  0.41039   0.10815701247
#
# Calls 243302
# Epoch:  84  individuals:  200  best fitness:  0.41039   0.10990156795999999
# Epoch:  84  individuals:  200  best fitness:  0.41039   0.1116811338
#
# Calls 246134
# Epoch:  85  individuals:  200  best fitness:  0.41039   0.11177894517
# Epoch:  85  individuals:  200  best fitness:  0.41039   0.11373355728
#
# Calls 249263
# Epoch:  86  individuals:  200  best fitness:  0.41039   0.11561256706
# Epoch:  86  individuals:  200  best fitness:  0.41039   0.1158036796
#
# Calls 252215
# Epoch:  87  individuals:  200  best fitness:  0.41039   0.12014569051
# Epoch:  87  individuals:  200  best fitness:  0.41039   0.15034455900000002
#
# Calls 255314
# Epoch:  88  individuals:  200  best fitness:  0.41039   0.1532455684
# Epoch:  88  individuals:  200  best fitness:  0.41039   0.1533356786
#
# Calls 258468
# Epoch:  89  individuals:  200  best fitness:  0.41039   0.1561337017
# Epoch:  89  individuals:  200  best fitness:  0.41039   0.1562346905
#
# Calls 261533
# Epoch:  90  individuals:  200  best fitness:  0.41039   0.1562234474
# Epoch:  90  individuals:  200  best fitness:  0.41039   0.1563447117
#
# Calls 264437
# Epoch:  91  individuals:  200  best fitness:  0.41039   0.156355901
# Epoch:  91  individuals:  200  best fitness:  0.41039   0.1590023466
#
# Calls 267653
# Epoch:  92  individuals:  200  best fitness:  0.41039   0.1590114688
# Epoch:  92  individuals:  200  best fitness:  0.41039   0.159034605
#
# Calls 270597
# Epoch:  93  individuals:  200  best fitness:  0.41039   0.1590245673
# Epoch:  93  individuals:  200  best fitness:  0.41039   0.1591234566
#
# Calls 273777
# Epoch:  94  individuals:  200  best fitness:  0.41039   0.1591346696
# Epoch:  94  individuals:  200  best fitness:  0.41039   0.1592245672
#
# Calls 276999
# Epoch:  95  individuals:  200  best fitness:  0.41039   0.1592244516
# Epoch:  95  individuals:  200  best fitness:  0.41039   0.15933589129999998
#
# Calls 279787
# Epoch:  96  individuals:  200  best fitness:  0.41039   0.1593456705
# Epoch:  96  individuals:  200  best fitness:  0.41039   0.1619112628
#
# Calls 282825
# Epoch:  97  individuals:  200  best fitness:  0.41039   0.16191346780000002
# Epoch:  97  individuals:  200  best fitness:  0.41039   0.16192366770000002
#
# Calls 285803
# Epoch:  98  individuals:  200  best fitness:  0.41039   0.16194458979999998
# Epoch:  98  individuals:  200  best fitness:  0.41039   0.1620134684
#
# Calls 288772
# Epoch:  99  individuals:  200  best fitness:  0.41039   0.1620136686
# Epoch:  99  individuals:  200  best fitness:  0.41039   0.1620345685
#
# Calls 291974
# Epoch:  100  individuals:  200  best fitness:  0.41039   0.1620344795
# Epoch:  100  individuals:  200  best fitness:  0.41039   0.1621235596
#
# Calls 295214
# Epoch:  101  individuals:  200  best fitness:  0.41039   0.1621225684
# Epoch:  101  individuals:  200  best fitness:  0.41039   0.16223446190000002
#
# Calls 298164
# Epoch:  102  individuals:  200  best fitness:  0.41039   0.16213456980000002
# Epoch:  102  individuals:  200  best fitness:  0.41039   0.16480156769999998
#
# Calls 301268
# Epoch:  103  individuals:  200  best fitness:  0.41039   0.162333583
# Epoch:  103  individuals:  200  best fitness:  0.41039   0.1649567351
#
# Calls 304306
# Epoch:  104  individuals:  200  best fitness:  0.41039   0.16482467969999998
# Epoch:  104  individuals:  200  best fitness:  0.41039   0.1594477907
#
# Calls 307136
# Epoch:  105  individuals:  200  best fitness:  0.41039   0.1650023464
# Epoch:  105  individuals:  200  best fitness:  0.41039   0.1621134585
#
# Calls 310461
# Epoch:  106  individuals:  200  best fitness:  0.41039   0.1650233674
# Epoch:  106  individuals:  200  best fitness:  0.41039   0.1650123565
#
# Calls 313274
# Epoch:  107  individuals:  200  best fitness:  0.41039   0.1651233565
# Epoch:  107  individuals:  200  best fitness:  0.41039   0.16512345690000002
#
# Calls 316286
# Epoch:  108  individuals:  200  best fitness:  0.41039   0.16522357199999999
# Epoch:  108  individuals:  200  best fitness:  0.41039   0.16524555770000002
#
# Calls 319370
# Epoch:  109  individuals:  200  best fitness:  0.41039   0.165335585
# Epoch:  109  individuals:  200  best fitness:  0.41039   0.1676796911
#
# Calls 322661
# Epoch:  110  individuals:  200  best fitness:  0.41039   0.1677046897
# Epoch:  110  individuals:  200  best fitness:  0.41039   0.1678044673
#
# Calls 325808
# Epoch:  111  individuals:  200  best fitness:  0.41039   0.1677125688
# Epoch:  111  individuals:  200  best fitness:  0.41039   0.1679122585
#
# Calls 328753
# Epoch:  112  individuals:  200  best fitness:  0.41039   0.1679111908
# Epoch:  112  individuals:  200  best fitness:  0.41039   0.1680114919
#
# Calls 331869
# Epoch:  113  individuals:  200  best fitness:  0.41039   0.1680125727
# Epoch:  113  individuals:  200  best fitness:  0.41039   0.1680246817
#
# Calls 334753
# Epoch:  114  individuals:  200  best fitness:  0.41039   0.1681234485
# Epoch:  114  individuals:  200  best fitness:  0.41039   0.16804577950000002
#
# Calls 337843
# Epoch:  115  individuals:  200  best fitness:  0.41039   0.16824779169999998
# Epoch:  115  individuals:  200  best fitness:  0.41039   0.1707455805
#
# Calls 340891
# Epoch:  116  individuals:  200  best fitness:  0.41039   0.1708017006
# Epoch:  116  individuals:  200  best fitness:  0.41039   0.1679555676
#
# Calls 343858
# Epoch:  117  individuals:  200  best fitness:  0.41039   0.1709124462
# Epoch:  117  individuals:  200  best fitness:  0.41039   0.1679555676
#
# Calls 346715
# Epoch:  118  individuals:  200  best fitness:  0.41039   0.17101169289999998
# Epoch:  118  individuals:  200  best fitness:  0.41039   0.19844890799999998
#
# Calls 349795
# Epoch:  119  individuals:  200  best fitness:  0.41039   0.1711135577
# Epoch:  119  individuals:  200  best fitness:  0.41039   0.198555806
#
# Calls 352885
# Epoch:  120  individuals:  200  best fitness:  0.41039   0.1717789028
# Epoch:  120  individuals:  200  best fitness:  0.41039   0.20233458999999998
#
# Calls 355973
# Epoch:  121  individuals:  182  best fitness:  0.41039   0.052123477795
# Epoch:  121  individuals:  158  best fitness:  0.41039   0.051901344677
#
# Calls 356562
# Epoch:  122  individuals:  200  best fitness:  0.41039   0.10400224597999999
# Epoch:  122  individuals:  200  best fitness:  0.41039   0.10025556971999999
#
# Calls 359076
# Epoch:  123  individuals:  200  best fitness:  0.41039   0.10811378927
# Epoch:  123  individuals:  200  best fitness:  0.41039   0.10612456794000001
#
# Calls 362114
# Epoch:  124  individuals:  200  best fitness:  0.41039   0.110144679
# Epoch:  124  individuals:  200  best fitness:  0.41039   0.10970566788
#
# Calls 365260
# Epoch:  125  individuals:  200  best fitness:  0.41039   0.11357126939
# Epoch:  125  individuals:  200  best fitness:  0.41039   0.11169145751000001
#
# Calls 368315
# Epoch:  126  individuals:  200  best fitness:  0.41039   0.11767790462000001
# Epoch:  126  individuals:  200  best fitness:  0.41039   0.11368224584
#
# Calls 371655
# Epoch:  127  individuals:  200  best fitness:  0.41039   0.1503456806
# Epoch:  127  individuals:  200  best fitness:  0.41039   0.11739024624
#
# Calls 374682
# Epoch:  128  individuals:  200  best fitness:  0.41039   0.15323367959999998
# Epoch:  128  individuals:  200  best fitness:  0.41039   0.15034577999999998
#
# Calls 377740
# Epoch:  129  individuals:  200  best fitness:  0.41039   0.15334681269999997
# Epoch:  129  individuals:  200  best fitness:  0.41039   0.15334573610000002
#
# Calls 380694
# Epoch:  130  individuals:  200  best fitness:  0.41039   0.15613358500000002
# Epoch:  130  individuals:  200  best fitness:  0.41039   0.1561335709
#
# Calls 383658
# Epoch:  131  individuals:  200  best fitness:  0.41039   0.1562345705
# Epoch:  131  individuals:  200  best fitness:  0.41039   0.156255906
#
# Calls 386841
# Epoch:  132  individuals:  200  best fitness:  0.41039   0.1564445684
# Epoch:  132  individuals:  200  best fitness:  0.41039   0.15644567839999998
#
# Calls 389799
# Epoch:  133  individuals:  200  best fitness:  0.41039   0.1590234576
# Epoch:  133  individuals:  200  best fitness:  0.41039   0.1590245575
#
# Calls 392894
# Epoch:  134  individuals:  200  best fitness:  0.41039   0.1591344933
# Epoch:  134  individuals:  200  best fitness:  0.41039   0.1591233594
#
# Calls 395871
# Epoch:  135  individuals:  200  best fitness:  0.41039   0.1592223456
# Epoch:  135  individuals:  200  best fitness:  0.41039   0.1591612349
#
# Calls 399008
# Epoch:  136  individuals:  200  best fitness:  0.41039   0.1619013362
# Epoch:  136  individuals:  200  best fitness:  0.41039   0.1592356684
#
# Calls 402057
# Epoch:  137  individuals:  200  best fitness:  0.41039   0.1620025817
# Epoch:  137  individuals:  200  best fitness:  0.41039   0.1618905695
#
# Calls 405044
# Epoch:  138  individuals:  200  best fitness:  0.41039   0.1620345708
# Epoch:  138  individuals:  200  best fitness:  0.41039   0.1619779144
#
# Calls 408064
# Epoch:  139  individuals:  200  best fitness:  0.41039   0.1621255573
# Epoch:  139  individuals:  200  best fitness:  0.41039   0.1620356817
#
# Calls 411306
# Epoch:  140  individuals:  200  best fitness:  0.41039   0.162138024
# Epoch:  140  individuals:  200  best fitness:  0.41039   0.1621222373
#
# Calls 414418
# Epoch:  141  individuals:  200  best fitness:  0.41039   0.1622348006
# Epoch:  141  individuals:  200  best fitness:  0.41039   0.16222339160000002
#
# Calls 417429
# Epoch:  142  individuals:  200  best fitness:  0.41039   0.1623567796
# Epoch:  142  individuals:  200  best fitness:  0.41039   0.1622345687
#
# Calls 420602
# Epoch:  143  individuals:  200  best fitness:  0.41039   0.16480013840000002
# Epoch:  143  individuals:  200  best fitness:  0.41039   0.1647845665
#
# Calls 423790
# Epoch:  144  individuals:  200  best fitness:  0.41039   0.1648146727
# Epoch:  144  individuals:  200  best fitness:  0.41039   0.1648445917
#
# Calls 426884
# Epoch:  145  individuals:  200  best fitness:  0.41039   0.1648915251
# Epoch:  145  individuals:  200  best fitness:  0.41039   0.16490601279999997
#
# Calls 429885
# Epoch:  146  individuals:  200  best fitness:  0.41039   0.1649126795
# Epoch:  146  individuals:  200  best fitness:  0.41039   0.1649455917
#
# Calls 432898
# Epoch:  147  individuals:  200  best fitness:  0.41039   0.1649490028
# Epoch:  147  individuals:  200  best fitness:  0.41039   0.1650124675
#
# Calls 435923
# Epoch:  148  individuals:  200  best fitness:  0.41039   0.16501237889999998
# Epoch:  148  individuals:  200  best fitness:  0.41039   0.16503356830000002
#
# Calls 439018
# Epoch:  149  individuals:  200  best fitness:  0.41039   0.1650233487
# Epoch:  149  individuals:  200  best fitness:  0.41039   0.16522335770000002
#
# Calls 441993
# Epoch:  150  individuals:  200  best fitness:  0.41039   0.16511367200000002
# Epoch:  150  individuals:  200  best fitness:  0.41039   0.16772457840000002
#
# Calls 445276
# Epoch:  151  individuals:  200  best fitness:  0.41039   0.16513480190000002
# Epoch:  151  individuals:  200  best fitness:  0.41039   0.16790455769999998
#
# Calls 450082
# Epoch:  152  individuals:  200  best fitness:  0.41039   0.1652222298
# Epoch:  152  individuals:  200  best fitness:  0.41039   0.1680112352
#
# Calls 453068
# Epoch:  153  individuals:  200  best fitness:  0.41039   0.1652455795
# Epoch:  153  individuals:  200  best fitness:  0.41039   0.16812567949999999
#
# Calls 456152
# Epoch:  154  individuals:  200  best fitness:  0.41039   0.1654446823
# Epoch:  154  individuals:  200  best fitness:  0.41039   0.168134569
#
# Calls 459348
# Epoch:  155  individuals:  200  best fitness:  0.41039   0.1676823473
# Epoch:  155  individuals:  200  best fitness:  0.41039   0.16823457160000002
#
# Calls 462636
# Epoch:  156  individuals:  200  best fitness:  0.41039   0.1678013795
# Epoch:  156  individuals:  200  best fitness:  0.41039   0.17060122849999998
#
# Calls 465688
# Epoch:  157  individuals:  200  best fitness:  0.41039   0.167812564
# Epoch:  157  individuals:  200  best fitness:  0.41039   0.1709111686
#
# Calls 468751
# Epoch:  158  individuals:  200  best fitness:  0.41039   0.1679016896
# Epoch:  158  individuals:  200  best fitness:  0.41039   0.1709355817
#
# Calls 471989
# Epoch:  159  individuals:  200  best fitness:  0.41039   0.1679355685
# Epoch:  159  individuals:  200  best fitness:  0.41039   0.17100345949999998
#
# Calls 474998
# Epoch:  160  individuals:  200  best fitness:  0.41039   0.1680045595
# Epoch:  160  individuals:  200  best fitness:  0.41039   0.17122370409999998
#
# Calls 478113
# Epoch:  161  individuals:  149  best fitness:  0.41039   0.052781136793
# Epoch:  161  individuals:  168  best fitness:  0.41039   0.052792234229
#
# Calls 478656
# Epoch:  162  individuals:  200  best fitness:  0.41039   0.09844466905999999
# Epoch:  162  individuals:  200  best fitness:  0.41039   0.10400134451
#
# Calls 481063
# Epoch:  163  individuals:  200  best fitness:  0.41039   0.10614555738
# Epoch:  163  individuals:  200  best fitness:  0.41039   0.10791233497000001
#
# Calls 483978
# Epoch:  164  individuals:  200  best fitness:  0.41039   0.10978055574
# Epoch:  164  individuals:  200  best fitness:  0.41039   0.11002236127000001
#
# Calls 486988
# Epoch:  165  individuals:  200  best fitness:  0.41039   0.1116923671
# Epoch:  165  individuals:  200  best fitness:  0.41039   0.1120224592
#
# Calls 490321
# Epoch:  166  individuals:  200  best fitness:  0.41039   0.11393455689
# Epoch:  166  individuals:  200  best fitness:  0.41039   0.11581125798
#
# Calls 493515
# Epoch:  167  individuals:  200  best fitness:  0.41039   0.1475566899
# Epoch:  167  individuals:  200  best fitness:  0.41039   0.1503348021
#
# Calls 496671
# Epoch:  168  individuals:  200  best fitness:  0.41039   0.153446782
# Epoch:  168  individuals:  200  best fitness:  0.41039   0.15334555960000001
#
# Calls 499703
# Epoch:  169  individuals:  200  best fitness:  0.41039   0.1561355686
# Epoch:  169  individuals:  200  best fitness:  0.41039   0.156135623
#
# Calls 502766
# Epoch:  170  individuals:  200  best fitness:  0.41039   0.1562346705
# Epoch:  170  individuals:  200  best fitness:  0.41039   0.1590015606
#
# Calls 505825
# Epoch:  171  individuals:  200  best fitness:  0.41039   0.15635691510000002
# Epoch:  171  individuals:  200  best fitness:  0.41039   0.15902341290000002
#
# Calls 508699
# Epoch:  172  individuals:  200  best fitness:  0.41039   0.1590024562
# Epoch:  172  individuals:  200  best fitness:  0.41039   0.15912466979999998
#
# Calls 511791
# Epoch:  173  individuals:  200  best fitness:  0.41039   0.1590334784
# Epoch:  173  individuals:  200  best fitness:  0.41039   0.15924446169999998
#
# Calls 515039
# Epoch:  174  individuals:  200  best fitness:  0.41039   0.1591235739
# Epoch:  174  individuals:  200  best fitness:  0.41039   0.15934567989999998
#
# Calls 518032
# Epoch:  175  individuals:  200  best fitness:  0.41039   0.1592225807
# Epoch:  175  individuals:  200  best fitness:  0.41039   0.1618922863
#
# Calls 521073
# Epoch:  176  individuals:  200  best fitness:  0.41039   0.1593456807
# Epoch:  176  individuals:  200  best fitness:  0.41039   0.16191223529999998
#
# Calls 524045
# Epoch:  177  individuals:  200  best fitness:  0.41039   0.1619011243
# Epoch:  177  individuals:  200  best fitness:  0.41039   0.1620112466
#
# Calls 526862
# Epoch:  178  individuals:  200  best fitness:  0.41039   0.1619077907
# Epoch:  178  individuals:  200  best fitness:  0.41039   0.1620237008
#
# Calls 529996
# Epoch:  179  individuals:  200  best fitness:  0.41039   0.1620022348
# Epoch:  179  individuals:  200  best fitness:  0.41039   0.16211555730000002
#
# Calls 533020
# Epoch:  180  individuals:  200  best fitness:  0.41039   0.1621127784
# Epoch:  180  individuals:  200  best fitness:  0.41039   0.1621456795
#
# Calls 536243
# Epoch:  181  individuals:  200  best fitness:  0.41039   0.162159002
# Epoch:  181  individuals:  200  best fitness:  0.41039   0.1648111906
#
# Calls 539438
# Epoch:  182  individuals:  200  best fitness:  0.41039   0.1623455949
# Epoch:  182  individuals:  200  best fitness:  0.41039   0.16489223949999998
#
# Calls 542369
# Epoch:  183  individuals:  200  best fitness:  0.41039   0.1647856841
# Epoch:  183  individuals:  200  best fitness:  0.41039   0.16490338170000002
#
# Calls 545512
# Epoch:  184  individuals:  200  best fitness:  0.41039   0.1651225905
# Epoch:  184  individuals:  200  best fitness:  0.41039   0.1649266818
#
# Calls 548443
# Epoch:  185  individuals:  200  best fitness:  0.41039   0.1591345684
# Epoch:  185  individuals:  200  best fitness:  0.41039   0.16502335740000001
#
# Calls 551389
# Epoch:  186  individuals:  200  best fitness:  0.41039   0.16512344769999998
# Epoch:  186  individuals:  200  best fitness:  0.41039   0.1651145951
#
# Calls 554433
# Epoch:  187  individuals:  200  best fitness:  0.41039   0.1676916684
# Epoch:  187  individuals:  200  best fitness:  0.41039   0.1651334683
#
# Calls 557301
# Epoch:  188  individuals:  200  best fitness:  0.41039   0.1677793873
# Epoch:  188  individuals:  200  best fitness:  0.41039   0.1652233462
#
# Calls 560207
# Epoch:  189  individuals:  200  best fitness:  0.41039   0.1679336039
# Epoch:  189  individuals:  200  best fitness:  0.41039   0.1676786133
#
# Calls 563249
# Epoch:  190  individuals:  200  best fitness:  0.41039   0.198445565
# Epoch:  190  individuals:  200  best fitness:  0.41039   0.1677677829
#
# Calls 565932
# Epoch:  191  individuals:  200  best fitness:  0.41039   0.19845890700000002
# Epoch:  191  individuals:  200  best fitness:  0.41039   0.1678461228
#
# Calls 568797
# Epoch:  192  individuals:  200  best fitness:  0.41039   0.202367795
# Epoch:  192  individuals:  200  best fitness:  0.41039   0.1679245697
#
# Calls 571741
# Epoch:  193  individuals:  200  best fitness:  0.41039   0.1594444684
# Epoch:  193  individuals:  200  best fitness:  0.41039   0.16793381170000002
#
# Calls 574439
# Epoch:  194  individuals:  200  best fitness:  0.41039   0.1648902573
# Epoch:  194  individuals:  200  best fitness:  0.41039   0.16801457
#
# Calls 577583
# Epoch:  195  individuals:  200  best fitness:  0.41039   0.202448228
# Epoch:  195  individuals:  200  best fitness:  0.41039   0.16804567990000002
#
# Calls 580171
# Epoch:  196  individuals:  200  best fitness:  0.41039   0.206240463
# Epoch:  196  individuals:  200  best fitness:  0.41039   0.16823470399999998
#
# Calls 582753
# Epoch:  197  individuals:  200  best fitness:  0.41039   0.210116797
# Epoch:  197  individuals:  200  best fitness:  0.41039   0.1705612677
#
# Calls 585461
# Epoch:  198  individuals:  200  best fitness:  0.41039   0.214011351
# Epoch:  198  individuals:  200  best fitness:  0.41039   0.1706026821
#
# Calls 588447
# Epoch:  199  individuals:  200  best fitness:  0.41039   0.25922686
# Epoch:  199  individuals:  200  best fitness:  0.41039   0.1707114572
#
# Calls 591182
# Epoch:  200  individuals:  200  best fitness:  0.41039   0.26416786999999997
# Epoch:  200  individuals:  200  best fitness:  0.41039   0.1709005675
#
# Calls 594175
# Epoch:  201  individuals:  200  best fitness:  0.41039   0.052779235706
# Epoch:  201  individuals:  162  best fitness:  0.41039   0.052579223385
#
# Calls 594820
# Epoch:  202  individuals:  200  best fitness:  0.41039   0.10245568119
# Epoch:  202  individuals:  200  best fitness:  0.41039   0.10023567029
#
# Calls 597322
# Epoch:  203  individuals:  200  best fitness:  0.41039   0.10781135699000001
# Epoch:  203  individuals:  200  best fitness:  0.41039   0.10780247787000001
#
# Calls 600408
# Epoch:  204  individuals:  200  best fitness:  0.41039   0.10981237808000001
# Epoch:  204  individuals:  200  best fitness:  0.41039   0.1100066924
#
# Calls 603393
# Epoch:  205  individuals:  200  best fitness:  0.41039   0.11182555784999999
# Epoch:  205  individuals:  200  best fitness:  0.41039   0.11211123340000001
#
# Calls 606544
# Epoch:  206  individuals:  200  best fitness:  0.41039   0.11569234483
# Epoch:  206  individuals:  200  best fitness:  0.41039   0.1141113569
#
# Calls 609621
# Epoch:  207  individuals:  200  best fitness:  0.41039   0.15034566870000002
# Epoch:  207  individuals:  200  best fitness:  0.41039   0.147466894
#
# Calls 612404
# Epoch:  208  individuals:  200  best fitness:  0.41039   0.1534666895
# Epoch:  208  individuals:  200  best fitness:  0.41039   0.1532346724
#
# Calls 615429
# Epoch:  209  individuals:  200  best fitness:  0.41039   0.15623355900000002
# Epoch:  209  individuals:  200  best fitness:  0.41039   0.1534679029
#
# Calls 618431
# Epoch:  210  individuals:  200  best fitness:  0.41039   0.15644689080000002
# Epoch:  210  individuals:  200  best fitness:  0.41039   0.1561578007
#
# Calls 621453
# Epoch:  211  individuals:  200  best fitness:  0.41039   0.15903356070000002
# Epoch:  211  individuals:  200  best fitness:  0.41039   0.15624580059999998
#
# Calls 624287
# Epoch:  212  individuals:  200  best fitness:  0.41039   0.1591458054
# Epoch:  212  individuals:  200  best fitness:  0.41039   0.1590123375
#
# Calls 627204
# Epoch:  213  individuals:  200  best fitness:  0.41039   0.15933567869999998
# Epoch:  213  individuals:  200  best fitness:  0.41039   0.1591113686
#
# Calls 630341
# Epoch:  214  individuals:  200  best fitness:  0.41039   0.1619023564
# Epoch:  214  individuals:  200  best fitness:  0.41039   0.1591234486
#
# Calls 633465
# Epoch:  215  individuals:  200  best fitness:  0.41039   0.1619446794
# Epoch:  215  individuals:  200  best fitness:  0.41039   0.1591347117
#
# Calls 636595
# Epoch:  216  individuals:  200  best fitness:  0.41039   0.1620222384
# Epoch:  216  individuals:  200  best fitness:  0.41039   0.1592444467
#
# Calls 639747
# Epoch:  217  individuals:  200  best fitness:  0.41039   0.16202566799999998
# Epoch:  217  individuals:  200  best fitness:  0.41039   0.15944490120000002
#
# Calls 642811
# Epoch:  218  individuals:  200  best fitness:  0.41039   0.16211579
# Epoch:  218  individuals:  200  best fitness:  0.41039   0.1619034675
#
# Calls 645938
# Epoch:  219  individuals:  200  best fitness:  0.41039   0.1621356673
# Epoch:  219  individuals:  200  best fitness:  0.41039   0.161923463
#
# Calls 648990
# Epoch:  220  individuals:  200  best fitness:  0.41039   0.1623337894
# Epoch:  220  individuals:  200  best fitness:  0.41039   0.16194456740000002
#
# Calls 651874
# Epoch:  221  individuals:  200  best fitness:  0.41039   0.1624679016
# Epoch:  221  individuals:  200  best fitness:  0.41039   0.1620013461
#
# Calls 655115
# Epoch:  222  individuals:  200  best fitness:  0.41039   0.164814705
# Epoch:  222  individuals:  200  best fitness:  0.41039   0.1620144929
#
# Calls 658452
# Epoch:  223  individuals:  200  best fitness:  0.41039   0.1649234684
# Epoch:  223  individuals:  200  best fitness:  0.41039   0.16202356990000003
#
# Calls 661537
# Epoch:  224  individuals:  200  best fitness:  0.41039   0.16502346739999998
# Epoch:  224  individuals:  200  best fitness:  0.41039   0.1621169139
#
# Calls 664770
# Epoch:  225  individuals:  200  best fitness:  0.41039   0.1651222363
# Epoch:  225  individuals:  200  best fitness:  0.41039   0.1622455675
#
# Calls 667805
# Epoch:  226  individuals:  200  best fitness:  0.41039   0.1651235687
# Epoch:  226  individuals:  200  best fitness:  0.41039   0.1624557933
#
# Calls 670953
# Epoch:  227  individuals:  200  best fitness:  0.41039   0.1652339021
# Epoch:  227  individuals:  200  best fitness:  0.41039   0.16480036960000002
#
# Calls 674139
# Epoch:  228  individuals:  200  best fitness:  0.41039   0.16523677950000001
# Epoch:  228  individuals:  200  best fitness:  0.41039   0.16489135870000002
#
# Calls 677396
# Epoch:  229  individuals:  200  best fitness:  0.41039   0.1654567343
# Epoch:  229  individuals:  200  best fitness:  0.41039   0.1650011244
#
# Calls 680630
# Epoch:  230  individuals:  200  best fitness:  0.41039   0.1676811694
# Epoch:  230  individuals:  200  best fitness:  0.41039   0.1650134563
#
# Calls 683614
# Epoch:  231  individuals:  200  best fitness:  0.41039   0.1676901339
# Epoch:  231  individuals:  200  best fitness:  0.41039   0.1650567813
#
# Calls 686557
# Epoch:  232  individuals:  200  best fitness:  0.41039   0.1677114673
# Epoch:  232  individuals:  200  best fitness:  0.41039   0.1651224684
#
# Calls 689640
# Epoch:  233  individuals:  200  best fitness:  0.41039   0.1677335698
# Epoch:  233  individuals:  200  best fitness:  0.41039   0.1652445707
#
# Calls 692865
# Epoch:  234  individuals:  200  best fitness:  0.41039   0.16780135799999998
# Epoch:  234  individuals:  200  best fitness:  0.41039   0.1677036794
#
# Calls 695968
# Epoch:  235  individuals:  200  best fitness:  0.41039   0.16791279180000002
# Epoch:  235  individuals:  200  best fitness:  0.41039   0.1705646927
#
# Calls 699108
# Epoch:  236  individuals:  200  best fitness:  0.41039   0.168125912
# Epoch:  236  individuals:  200  best fitness:  0.41039   0.1737022575
#
# Calls 702103
# Epoch:  237  individuals:  200  best fitness:  0.41039   0.1683350117
# Epoch:  237  individuals:  200  best fitness:  0.41039   0.202466816
#
# Calls 704995
# Epoch:  238  individuals:  200  best fitness:  0.41039   0.1705715716
# Epoch:  238  individuals:  200  best fitness:  0.41039   0.162002335
#
# Calls 708073
# Epoch:  239  individuals:  200  best fitness:  0.41039   0.1706802684
# Epoch:  239  individuals:  200  best fitness:  0.41039   0.1621245705
#
# Calls 711205
# Epoch:  240  individuals:  200  best fitness:  0.41039   0.1707916796
# Epoch:  240  individuals:  200  best fitness:  0.41039   0.1679236687
#
# Calls 714376
# Epoch:  241  individuals:  183  best fitness:  0.41039   0.052012335717
# Epoch:  241  individuals:  200  best fitness:  0.41039   0.052790335586
#
# Calls 715070
# Epoch:  242  individuals:  200  best fitness:  0.41039   0.10413669052
# Epoch:  242  individuals:  200  best fitness:  0.41039   0.10402556895
#
# Calls 718125
# Epoch:  243  individuals:  200  best fitness:  0.41039   0.10803347051000001
# Epoch:  243  individuals:  200  best fitness:  0.41039   0.10790245563
#
# Calls 721056
# Epoch:  244  individuals:  200  best fitness:  0.41039   0.11000222700000001
# Epoch:  244  individuals:  200  best fitness:  0.41039   0.11000223709
#
# Calls 724145
# Epoch:  245  individuals:  200  best fitness:  0.41039   0.11180235909
# Epoch:  245  individuals:  200  best fitness:  0.41039   0.11350122475
#
# Calls 727274
# Epoch:  246  individuals:  200  best fitness:  0.41039   0.11423455801999999
# Epoch:  246  individuals:  200  best fitness:  0.41039   0.11567792371999999
#
# Calls 730481
# Epoch:  247  individuals:  200  best fitness:  0.41039   0.11927123405000001
# Epoch:  247  individuals:  200  best fitness:  0.41039   0.1445556717
#
# Calls 733557
# Epoch:  248  individuals:  200  best fitness:  0.41039   0.1504446683
# Epoch:  248  individuals:  200  best fitness:  0.41039   0.15323591179999999
#
# Calls 736825
# Epoch:  249  individuals:  200  best fitness:  0.41039   0.1533355684
# Epoch:  249  individuals:  200  best fitness:  0.41039   0.1534666799
#
# Calls 740085
# Epoch:  250  individuals:  200  best fitness:  0.41039   0.15611237209999998
# Epoch:  250  individuals:  200  best fitness:  0.41039   0.1562223364
#
# Calls 743234
# Epoch:  251  individuals:  200  best fitness:  0.41039   0.1561556911
# Epoch:  251  individuals:  200  best fitness:  0.41039   0.1563345797
#
# Calls 746119
# Epoch:  252  individuals:  200  best fitness:  0.41039   0.1562490132
# Epoch:  252  individuals:  200  best fitness:  0.41039   0.1590122685
#
# Calls 749195
# Epoch:  253  individuals:  200  best fitness:  0.41039   0.15901345609999998
# Epoch:  253  individuals:  200  best fitness:  0.41039   0.1591115797
#
# Calls 752237
# Epoch:  254  individuals:  200  best fitness:  0.41039   0.1591124578
# Epoch:  254  individuals:  200  best fitness:  0.41039   0.1592334487
#
# Calls 755371
# Epoch:  255  individuals:  200  best fitness:  0.41039   0.1591445819
# Epoch:  255  individuals:  200  best fitness:  0.41039   0.1594444575
#
# Calls 758387
# Epoch:  256  individuals:  200  best fitness:  0.41039   0.1593668941
# Epoch:  256  individuals:  200  best fitness:  0.41039   0.1619035796
#
# Calls 761566
# Epoch:  257  individuals:  200  best fitness:  0.41039   0.1619036918
# Epoch:  257  individuals:  200  best fitness:  0.41039   0.16200357940000001
#
# Calls 764659
# Epoch:  258  individuals:  200  best fitness:  0.41039   0.1619246039
# Epoch:  258  individuals:  200  best fitness:  0.41039   0.1620255807
#
# Calls 767825
# Epoch:  259  individuals:  200  best fitness:  0.41039   0.16200191290000002
# Epoch:  259  individuals:  200  best fitness:  0.41039   0.1621245675
#
# Calls 770906
# Epoch:  260  individuals:  200  best fitness:  0.41039   0.1620337918
# Epoch:  260  individuals:  200  best fitness:  0.41039   0.1622334839
#
# Calls 773758
# Epoch:  261  individuals:  200  best fitness:  0.41039   0.1621146685
# Epoch:  261  individuals:  200  best fitness:  0.41039   0.16477934830000002
#
# Calls 777008
# Epoch:  262  individuals:  200  best fitness:  0.41039   0.1622235695
# Epoch:  262  individuals:  200  best fitness:  0.41039   0.164792471
#
# Calls 780049
# Epoch:  263  individuals:  200  best fitness:  0.41039   0.1622445564
# Epoch:  263  individuals:  200  best fitness:  0.41039   0.1648114598
#
# Calls 783146
# Epoch:  264  individuals:  200  best fitness:  0.41039   0.16245677960000002
# Epoch:  264  individuals:  200  best fitness:  0.41039   0.1649015686
#
# Calls 786410
# Epoch:  265  individuals:  200  best fitness:  0.41039   0.1647890161
# Epoch:  265  individuals:  200  best fitness:  0.41039   0.1649233806
#
# Calls 789650
# Epoch:  266  individuals:  200  best fitness:  0.41039   0.1648111791
# Epoch:  266  individuals:  200  best fitness:  0.41039   0.1650124576
#
# Calls 792776
# Epoch:  267  individuals:  200  best fitness:  0.41039   0.1648937795
# Epoch:  267  individuals:  200  best fitness:  0.41039   0.1651135839
#
# Calls 796109
# Epoch:  268  individuals:  200  best fitness:  0.41039   0.1649235573
# Epoch:  268  individuals:  200  best fitness:  0.41039   0.1651337929
#
# Calls 799223
# Epoch:  269  individuals:  200  best fitness:  0.41039   0.1650022371
# Epoch:  269  individuals:  200  best fitness:  0.41039   0.1652601128
#
# Calls 802310
# Epoch:  270  individuals:  200  best fitness:  0.41039   0.1650133865
# Epoch:  270  individuals:  200  best fitness:  0.41039   0.16544680180000002
#
# Calls 805603
# Epoch:  271  individuals:  200  best fitness:  0.41039   0.1650234906
# Epoch:  271  individuals:  200  best fitness:  0.41039   0.1677025018
#
# Calls 808775
# Epoch:  272  individuals:  200  best fitness:  0.41039   0.1652259007
# Epoch:  272  individuals:  200  best fitness:  0.41039   0.1678157018
#
# Calls 811831
# Epoch:  273  individuals:  200  best fitness:  0.41039   0.16533568070000002
# Epoch:  273  individuals:  200  best fitness:  0.41039   0.16790159270000002
#
# Calls 814786
# Epoch:  274  individuals:  200  best fitness:  0.41039   0.1676800574
# Epoch:  274  individuals:  200  best fitness:  0.41039   0.1680135687
#
# Calls 817789
# Epoch:  275  individuals:  200  best fitness:  0.41039   0.1677133696
# Epoch:  275  individuals:  200  best fitness:  0.41039   0.1681355642
#
# Calls 820717
# Epoch:  276  individuals:  200  best fitness:  0.41039   0.1677156785
# Epoch:  276  individuals:  200  best fitness:  0.41039   0.168334779
#
# Calls 823937
# Epoch:  277  individuals:  200  best fitness:  0.41039   0.1678257895
# Epoch:  277  individuals:  200  best fitness:  0.41039   0.16835568280000002
#
# Calls 826954
# Epoch:  278  individuals:  200  best fitness:  0.41039   0.168036901
# Epoch:  278  individuals:  200  best fitness:  0.41039   0.1705915574
#
# Calls 830159
# Epoch:  279  individuals:  200  best fitness:  0.41039   0.1683351243
# Epoch:  279  individuals:  200  best fitness:  0.41039   0.1706902263
#
# Calls 833266
# Epoch:  280  individuals:  200  best fitness:  0.41039   0.1706035918
# Epoch:  280  individuals:  200  best fitness:  0.41039   0.1708024675
#
# Calls 836374
# Epoch:  281  individuals:  165  best fitness:  0.41039   0.052135679007
# Epoch:  281  individuals:  180  best fitness:  0.41039   0.05270167012
#
# Calls 836974
# Epoch:  282  individuals:  200  best fitness:  0.41039   0.10233457794999999
# Epoch:  282  individuals:  200  best fitness:  0.41039   0.10422346683
#
# Calls 839741
# Epoch:  283  individuals:  200  best fitness:  0.41039   0.10779446017
# Epoch:  283  individuals:  200  best fitness:  0.41039   0.10801224539
#
# Calls 842470
# Epoch:  284  individuals:  200  best fitness:  0.41039   0.10970224608
# Epoch:  284  individuals:  200  best fitness:  0.41039   0.11002245786
#
# Calls 845236
# Epoch:  285  individuals:  200  best fitness:  0.41039   0.11170346895
# Epoch:  285  individuals:  200  best fitness:  0.41039   0.11190138018000001
#
# Calls 848370
# Epoch:  286  individuals:  200  best fitness:  0.41039   0.11222456810999999
# Epoch:  286  individuals:  200  best fitness:  0.41039   0.11558000522
#
# Calls 851474
# Epoch:  287  individuals:  200  best fitness:  0.41039   0.11758944572999999
# Epoch:  287  individuals:  200  best fitness:  0.41039   0.1503567121
#
# Calls 854530
# Epoch:  288  individuals:  200  best fitness:  0.41039   0.1504467133
# Epoch:  288  individuals:  200  best fitness:  0.41039   0.1533366794
#
# Calls 857586
# Epoch:  289  individuals:  200  best fitness:  0.41039   0.15334559279999999
# Epoch:  289  individuals:  200  best fitness:  0.41039   0.1536677811
#
# Calls 860668
# Epoch:  290  individuals:  200  best fitness:  0.41039   0.1561234609
# Epoch:  290  individuals:  200  best fitness:  0.41039   0.1562346017
#
# Calls 863914
# Epoch:  291  individuals:  200  best fitness:  0.41039   0.1562356785
# Epoch:  291  individuals:  200  best fitness:  0.41039   0.1566891232
#
# Calls 867116
# Epoch:  292  individuals:  200  best fitness:  0.41039   0.1590112344
# Epoch:  292  individuals:  200  best fitness:  0.41039   0.15903446880000002
#
# Calls 870275
# Epoch:  293  individuals:  200  best fitness:  0.41039   0.15902455850000002
# Epoch:  293  individuals:  200  best fitness:  0.41039   0.15922450059999999
#
# Calls 873391
# Epoch:  294  individuals:  200  best fitness:  0.41039   0.1591256818
# Epoch:  294  individuals:  200  best fitness:  0.41039   0.1593580007
#
# Calls 876533
# Epoch:  295  individuals:  200  best fitness:  0.41039   0.1592236796
# Epoch:  295  individuals:  200  best fitness:  0.41039   0.16190146830000002
#
# Calls 879782
# Epoch:  296  individuals:  200  best fitness:  0.41039   0.1592467906
# Epoch:  296  individuals:  200  best fitness:  0.41039   0.1619135906
#
# Calls 882873
# Epoch:  297  individuals:  200  best fitness:  0.41039   0.15956900289999998
# Epoch:  297  individuals:  200  best fitness:  0.41039   0.1619445584
#
# Calls 886029
# Epoch:  298  individuals:  200  best fitness:  0.41039   0.16192348050000002
# Epoch:  298  individuals:  200  best fitness:  0.41039   0.1620245672
#
# Calls 889050
# Epoch:  299  individuals:  200  best fitness:  0.41039   0.1620123819
# Epoch:  299  individuals:  200  best fitness:  0.41039   0.1621345674
#
# Calls 892009
# Epoch:  300  individuals:  200  best fitness:  0.41039   0.1620357018
# Epoch:  300  individuals:  200  best fitness:  0.41039   0.1624470238
#
# Calls 895034
# Epoch:  301  individuals:  200  best fitness:  0.41039   0.1621224474
# Epoch:  301  individuals:  200  best fitness:  0.41039   0.1648156706
#
# Calls 898189
# Epoch:  302  individuals:  200  best fitness:  0.41039   0.162224459
# Epoch:  302  individuals:  200  best fitness:  0.41039   0.16490114539999998
#
# Calls 901567
# Epoch:  303  individuals:  200  best fitness:  0.41039   0.1622357117
# Epoch:  303  individuals:  200  best fitness:  0.41039   0.1649348166
#
# Calls 904675
# Epoch:  304  individuals:  200  best fitness:  0.41039   0.1647924505
# Epoch:  304  individuals:  200  best fitness:  0.41039   0.1650246807
#
# Calls 907748
# Epoch:  305  individuals:  200  best fitness:  0.41039   0.1648112392
# ...
# Epoch:  9901  individuals:  200  best fitness:  0.4541   0.1622556694
#
# Calls 29348108
# Epoch:  9902  individuals:  200  best fitness:  0.4541   0.1621346049
# Epoch:  9902  individuals:  200  best fitness:  0.4541   0.16245668989999998
#
# Calls 29351259
# Epoch:  9903  individuals:  200  best fitness:  0.4541   0.1623334485
# Epoch:  9903  individuals:  200  best fitness:  0.4541   0.1647805138
#
# Calls 29354380
# Epoch:  9904  individuals:  200  best fitness:  0.4541   0.1623567806
# Epoch:  9904  individuals:  200  best fitness:  0.4541   0.1648022589
#
# Calls 29357446
# Epoch:  9905  individuals:  200  best fitness:  0.4541   0.1647904686
# Epoch:  9905  individuals:  200  best fitness:  0.4541   0.164890705
#
# Calls 29360516
# Epoch:  9906  individuals:  200  best fitness:  0.4541   0.1649013731
# Epoch:  9906  individuals:  200  best fitness:  0.4541   0.16490567279999999
#
# Calls 29363583
# Epoch:  9907  individuals:  200  best fitness:  0.4541   0.16494556840000002
# Epoch:  9907  individuals:  200  best fitness:  0.4541   0.16491456880000002
#
# Calls 29366585
# Epoch:  9908  individuals:  200  best fitness:  0.4541   0.1650345796
# Epoch:  9908  individuals:  200  best fitness:  0.4541   0.1650111385
#
# Calls 29369728
# Epoch:  9909  individuals:  200  best fitness:  0.4541   0.1650455599
# Epoch:  9909  individuals:  200  best fitness:  0.4541   0.1650234588
#
# Calls 29372875
# Epoch:  9910  individuals:  200  best fitness:  0.4541   0.1652244705
# Epoch:  9910  individuals:  200  best fitness:  0.4541   0.1651345896
#
# Calls 29375839
# Epoch:  9911  individuals:  200  best fitness:  0.4541   0.1652460161
# Epoch:  9911  individuals:  200  best fitness:  0.4541   0.1652455929
#
# Calls 29378924
# Epoch:  9912  individuals:  200  best fitness:  0.4541   0.16768334759999998
# Epoch:  9912  individuals:  200  best fitness:  0.4541   0.16770122839999999
#
# Calls 29382087
# Epoch:  9913  individuals:  200  best fitness:  0.4541   0.1678115791
# Epoch:  9913  individuals:  200  best fitness:  0.4541   0.1677934474
#
# Calls 29385198
# Epoch:  9914  individuals:  200  best fitness:  0.4541   0.167902501
# Epoch:  9914  individuals:  200  best fitness:  0.4541   0.16780367499999999
#
# Calls 29388289
# Epoch:  9915  individuals:  200  best fitness:  0.4541   0.1682334561
# Epoch:  9915  individuals:  200  best fitness:  0.4541   0.16790014730000002
#
# Calls 29391415
# Epoch:  9916  individuals:  200  best fitness:  0.4541   0.1705914683
# Epoch:  9916  individuals:  200  best fitness:  0.4541   0.1680133562
#
# Calls 29394716
# Epoch:  9917  individuals:  200  best fitness:  0.4541   0.170746794
# Epoch:  9917  individuals:  200  best fitness:  0.4541   0.1680346906
#
# Calls 29397923
# Epoch:  9918  individuals:  200  best fitness:  0.4541   0.17083560080000001
# Epoch:  9918  individuals:  200  best fitness:  0.4541   0.16811123449999998
#
# Calls 29401078
# Epoch:  9919  individuals:  200  best fitness:  0.4541   0.1709113576
# Epoch:  9919  individuals:  200  best fitness:  0.4541   0.16814456849999998
#
# Calls 29404201
# Epoch:  9920  individuals:  200  best fitness:  0.4541   0.17101258949999998
# Epoch:  9920  individuals:  200  best fitness:  0.4541   0.16844458180000002
#
# Calls 29407457
# Epoch:  9921  individuals:  189  best fitness:  0.4541   0.052588914907
# Epoch:  9921  individuals:  197  best fitness:  0.4541   0.051834569007
#
# Calls 29408138
# Epoch:  9922  individuals:  200  best fitness:  0.4541   0.10245568908
# Epoch:  9922  individuals:  200  best fitness:  0.4541   0.10401245919
#
# Calls 29410987
# Epoch:  9923  individuals:  200  best fitness:  0.4541   0.10790024572
# Epoch:  9923  individuals:  200  best fitness:  0.4541   0.10803579007
#
# Calls 29413870
# Epoch:  9924  individuals:  200  best fitness:  0.4541   0.11056780017
# Epoch:  9924  individuals:  200  best fitness:  0.4541   0.11013370062
#
# Calls 29416925
# Epoch:  9925  individuals:  200  best fitness:  0.4541   0.11361236673000001
# Epoch:  9925  individuals:  200  best fitness:  0.4541   0.11233344585999999
#
# Calls 29420300
# Epoch:  9926  individuals:  200  best fitness:  0.4541   0.11989013896999999
# Epoch:  9926  individuals:  200  best fitness:  0.4541   0.11446811172
#
# Calls 29423697
# Epoch:  9927  individuals:  200  best fitness:  0.4541   0.15323567940000002
# Epoch:  9927  individuals:  200  best fitness:  0.4541   0.1475557895
#
# Calls 29426917
# Epoch:  9928  individuals:  200  best fitness:  0.4541   0.156122364
# Epoch:  9928  individuals:  200  best fitness:  0.4541   0.1532344751
#
# Calls 29430033
# Epoch:  9929  individuals:  200  best fitness:  0.4541   0.15613568079999998
# Epoch:  9929  individuals:  200  best fitness:  0.4541   0.1535566805
#
# Calls 29433081
# Epoch:  9930  individuals:  200  best fitness:  0.4541   0.1563345569
# Epoch:  9930  individuals:  200  best fitness:  0.4541   0.15623566779999998
#
# Calls 29436413
# Epoch:  9931  individuals:  200  best fitness:  0.4541   0.1590224569
# Epoch:  9931  individuals:  200  best fitness:  0.4541   0.15901334069999998
#
# Calls 29439565
# Epoch:  9932  individuals:  200  best fitness:  0.4541   0.15911236869999998
# Epoch:  9932  individuals:  200  best fitness:  0.4541   0.1591156027
#
# Calls 29442658
# Epoch:  9933  individuals:  200  best fitness:  0.4541   0.1591455906
# Epoch:  9933  individuals:  200  best fitness:  0.4541   0.15914788970000002
#
# Calls 29445808
# Epoch:  9934  individuals:  200  best fitness:  0.4541   0.15923456160000002
# Epoch:  9934  individuals:  200  best fitness:  0.4541   0.15934778489999998
#
# Calls 29448879
# Epoch:  9935  individuals:  200  best fitness:  0.4541   0.1594444577
# Epoch:  9935  individuals:  200  best fitness:  0.4541   0.1619013465
#
# Calls 29451886
# Epoch:  9936  individuals:  200  best fitness:  0.4541   0.1619124673
# Epoch:  9936  individuals:  200  best fitness:  0.4541   0.1619144593
#
# Calls 29454995
# Epoch:  9937  individuals:  200  best fitness:  0.4541   0.1620016798
# Epoch:  9937  individuals:  200  best fitness:  0.4541   0.1620122678
#
# Calls 29457859
# Epoch:  9938  individuals:  200  best fitness:  0.4541   0.1620356788
# Epoch:  9938  individuals:  200  best fitness:  0.4541   0.1620255687
#
# Calls 29460863
# Epoch:  9939  individuals:  200  best fitness:  0.4541   0.1621145683
# Epoch:  9939  individuals:  200  best fitness:  0.4541   0.1621123576
#
# Calls 29464145
# Epoch:  9940  individuals:  200  best fitness:  0.4541   0.1621355783
# Epoch:  9940  individuals:  200  best fitness:  0.4541   0.1622347905
#
# Calls 29467413
# Epoch:  9941  individuals:  200  best fitness:  0.4541   0.1622356686
# Epoch:  9941  individuals:  200  best fitness:  0.4541   0.16244679199999998
#
# Calls 29470608
# Epoch:  9942  individuals:  200  best fitness:  0.4541   0.1623557139
# Epoch:  9942  individuals:  200  best fitness:  0.4541   0.164800905
#
# Calls 29473690
# Epoch:  9943  individuals:  200  best fitness:  0.4541   0.1647922352
# Epoch:  9943  individuals:  200  best fitness:  0.4541   0.1648245577
#
# Calls 29476646
# Epoch:  9944  individuals:  200  best fitness:  0.4541   0.1648922907
# Epoch:  9944  individuals:  200  best fitness:  0.4541   0.16491127979999998
#
# Calls 29479819
# Epoch:  9945  individuals:  200  best fitness:  0.4541   0.1650145589
# Epoch:  9945  individuals:  200  best fitness:  0.4541   0.1649238009
#
# Calls 29482994
# Epoch:  9946  individuals:  200  best fitness:  0.4541   0.1650456913
# Epoch:  9946  individuals:  200  best fitness:  0.4541   0.1650256809
#
# Calls 29485985
# Epoch:  9947  individuals:  200  best fitness:  0.4541   0.1651234454
# Epoch:  9947  individuals:  200  best fitness:  0.4541   0.1651223712
#
# Calls 29488989
# Epoch:  9948  individuals:  200  best fitness:  0.4541   0.16522335100000002
# Epoch:  9948  individuals:  200  best fitness:  0.4541   0.1651568939
#
# Calls 29492101
# Epoch:  9949  individuals:  200  best fitness:  0.4541   0.16523457830000002
# Epoch:  9949  individuals:  200  best fitness:  0.4541   0.1652369171
#
# Calls 29495219
# Epoch:  9950  individuals:  200  best fitness:  0.4541   0.1677113375
# Epoch:  9950  individuals:  200  best fitness:  0.4541   0.16545790289999998
#
# Calls 29498488
# Epoch:  9951  individuals:  200  best fitness:  0.4541   0.1677902473
# Epoch:  9951  individuals:  200  best fitness:  0.4541   0.16771344719999998
#
# Calls 29501793
# Epoch:  9952  individuals:  200  best fitness:  0.4541   0.1678145796
# Epoch:  9952  individuals:  200  best fitness:  0.4541   0.16772224170000002
#
# Calls 29505048
# Epoch:  9953  individuals:  200  best fitness:  0.4541   0.16792355720000002
# Epoch:  9953  individuals:  200  best fitness:  0.4541   0.16780146840000001
#
# Calls 29508287
# Epoch:  9954  individuals:  200  best fitness:  0.4541   0.1680055808
# Epoch:  9954  individuals:  200  best fitness:  0.4541   0.1678224602
#
# Calls 29511482
# Epoch:  9955  individuals:  200  best fitness:  0.4541   0.1680124904
# Epoch:  9955  individuals:  200  best fitness:  0.4541   0.1680114563
#
# Calls 29514600
# Epoch:  9956  individuals:  200  best fitness:  0.4541   0.16802336980000002
# Epoch:  9956  individuals:  200  best fitness:  0.4541   0.1682255897
#
# Calls 29517793
# Epoch:  9957  individuals:  200  best fitness:  0.4541   0.1682234928
# Epoch:  9957  individuals:  200  best fitness:  0.4541   0.1682468022
#
# Calls 29520900
# Epoch:  9958  individuals:  200  best fitness:  0.4541   0.1707911253
# Epoch:  9958  individuals:  200  best fitness:  0.4541   0.1705901306
#
# Calls 29524075
# Epoch:  9959  individuals:  200  best fitness:  0.4541   0.1710115696
# Epoch:  9959  individuals:  200  best fitness:  0.4541   0.1710011802
#
# Calls 29527204
# Epoch:  9960  individuals:  200  best fitness:  0.4541   0.1735733452
# Epoch:  9960  individuals:  200  best fitness:  0.4541   0.1735912244
#
# Calls 29530458
# Epoch:  9961  individuals:  198  best fitness:  0.4541   0.052222567151
# Epoch:  9961  individuals:  200  best fitness:  0.4541   0.052667893467
#
# Calls 29531184
# Epoch:  9962  individuals:  200  best fitness:  0.4541   0.1041369025
# Epoch:  9962  individuals:  200  best fitness:  0.4541   0.10412477796
#
# Calls 29534226
# Epoch:  9963  individuals:  200  best fitness:  0.4541   0.10968044795
# Epoch:  9963  individuals:  200  best fitness:  0.4541   0.10805577907
#
# Calls 29537090
# Epoch:  9964  individuals:  200  best fitness:  0.4541   0.11045566705
# Epoch:  9964  individuals:  200  best fitness:  0.4541   0.1115667924
#
# Calls 29540028
# Epoch:  9965  individuals:  200  best fitness:  0.4541   0.11360033566
# Epoch:  9965  individuals:  200  best fitness:  0.4541   0.1136845893
#
# Calls 29543151
# Epoch:  9966  individuals:  200  best fitness:  0.4541   0.11781123498
# Epoch:  9966  individuals:  200  best fitness:  0.4541   0.11563445898000001
#
# Calls 29546192
# Epoch:  9967  individuals:  200  best fitness:  0.4541   0.1533001227
# Epoch:  9967  individuals:  200  best fitness:  0.4541   0.14746002279999998
#
# Calls 29549515
# Epoch:  9968  individuals:  200  best fitness:  0.4541   0.15611468059999997
# Epoch:  9968  individuals:  200  best fitness:  0.4541   0.1504579118
#
# Calls 29552817
# Epoch:  9969  individuals:  200  best fitness:  0.4541   0.15623360049999999
# Epoch:  9969  individuals:  200  best fitness:  0.4541   0.15333347860000002
#
# Calls 29555939
# Epoch:  9970  individuals:  200  best fitness:  0.4541   0.1590012573
# Epoch:  9970  individuals:  200  best fitness:  0.4541   0.1561233466
#
# Calls 29559121
# Epoch:  9971  individuals:  200  best fitness:  0.4541   0.15902355829999998
# Epoch:  9971  individuals:  200  best fitness:  0.4541   0.1561357452
#
# Calls 29562207
# Epoch:  9972  individuals:  200  best fitness:  0.4541   0.1591344587
# Epoch:  9972  individuals:  200  best fitness:  0.4541   0.1562336017
#
# Calls 29565305
# Epoch:  9973  individuals:  200  best fitness:  0.4541   0.1592337909
# Epoch:  9973  individuals:  200  best fitness:  0.4541   0.1563690016
#
# Calls 29568250
# Epoch:  9974  individuals:  200  best fitness:  0.4541   0.1594455807
# Epoch:  9974  individuals:  200  best fitness:  0.4541   0.159023458
#
# Calls 29571302
# Epoch:  9975  individuals:  200  best fitness:  0.4541   0.1619012341
# Epoch:  9975  individuals:  200  best fitness:  0.4541   0.15913566969999998
#
# Calls 29574292
# Epoch:  9976  individuals:  200  best fitness:  0.4541   0.1619244788
# Epoch:  9976  individuals:  200  best fitness:  0.4541   0.1592666805
#
# Calls 29577427
# Epoch:  9977  individuals:  200  best fitness:  0.4541   0.16201333690000003
# Epoch:  9977  individuals:  200  best fitness:  0.4541   0.16190223459999997
#
# Calls 29580653
# Epoch:  9978  individuals:  200  best fitness:  0.4541   0.1621234898
# Epoch:  9978  individuals:  200  best fitness:  0.4541   0.1620112383
#
# Calls 29583743
# Epoch:  9979  individuals:  200  best fitness:  0.4541   0.16222346840000001
# Epoch:  9979  individuals:  200  best fitness:  0.4541   0.1621244687
#
# Calls 29586667
# Epoch:  9980  individuals:  200  best fitness:  0.4541   0.16245890059999998
# Epoch:  9980  individuals:  200  best fitness:  0.4541   0.1621689117
#
# Calls 29589761
# Epoch:  9981  individuals:  200  best fitness:  0.4541   0.1648025576
# Epoch:  9981  individuals:  200  best fitness:  0.4541   0.1624579241
#
# Calls 29592904
# Epoch:  9982  individuals:  200  best fitness:  0.4541   0.1648035898
# Epoch:  9982  individuals:  200  best fitness:  0.4541   0.1648922583
#
# Calls 29596030
# Epoch:  9983  individuals:  200  best fitness:  0.4541   0.1648248017
# Epoch:  9983  individuals:  200  best fitness:  0.4541   0.1649034486
#
# Calls 29599132
# Epoch:  9984  individuals:  200  best fitness:  0.4541   0.1649005687
# Epoch:  9984  individuals:  200  best fitness:  0.4541   0.1649112698
#
# Calls 29602290
# Epoch:  9985  individuals:  200  best fitness:  0.4541   0.16492356849999998
# Epoch:  9985  individuals:  200  best fitness:  0.4541   0.16501155750000002
#
# Calls 29605494
# Epoch:  9986  individuals:  200  best fitness:  0.4541   0.1650113574
# Epoch:  9986  individuals:  200  best fitness:  0.4541   0.1650255811
#
# Calls 29608638
# Epoch:  9987  individuals:  200  best fitness:  0.4541   0.1650223139
# Epoch:  9987  individuals:  200  best fitness:  0.4541   0.1651123805
#
# Calls 29611785
# Epoch:  9988  individuals:  200  best fitness:  0.4541   0.1651225676
# Epoch:  9988  individuals:  200  best fitness:  0.4541   0.1651478016
#
# Calls 29614992
# Epoch:  9989  individuals:  200  best fitness:  0.4541   0.1652255606
# Epoch:  9989  individuals:  200  best fitness:  0.4541   0.16523345660000002
#
# Calls 29617985
# Epoch:  9990  individuals:  200  best fitness:  0.4541   0.165467791
# Epoch:  9990  individuals:  200  best fitness:  0.4541   0.1652357907
#
# Calls 29621032
# Epoch:  9991  individuals:  200  best fitness:  0.4541   0.16768344640000002
# Epoch:  9991  individuals:  200  best fitness:  0.4541   0.1653556706
#
# Calls 29624134
# Epoch:  9992  individuals:  200  best fitness:  0.4541   0.1678126696
# Epoch:  9992  individuals:  200  best fitness:  0.4541   0.1677234483
#
# Calls 29627152
# Epoch:  9993  individuals:  200  best fitness:  0.4541   0.1679115699
# Epoch:  9993  individuals:  200  best fitness:  0.4541   0.1678012788
#
# Calls 29630200
# Epoch:  9994  individuals:  200  best fitness:  0.4541   0.1680123484
# Epoch:  9994  individuals:  200  best fitness:  0.4541   0.16782390290000002
#
# Calls 29633307
# Epoch:  9995  individuals:  200  best fitness:  0.4541   0.1681256708
# Epoch:  9995  individuals:  200  best fitness:  0.4541   0.1679135572
#
# Calls 29636379
# Epoch:  9996  individuals:  200  best fitness:  0.4541   0.1706811342
# Epoch:  9996  individuals:  200  best fitness:  0.4541   0.1680122363
#
# Calls 29639368
# Epoch:  9997  individuals:  200  best fitness:  0.4541   0.17074681290000002
# Epoch:  9997  individuals:  200  best fitness:  0.4541   0.16802359079999998
#
# Calls 29642598
# Epoch:  9998  individuals:  200  best fitness:  0.4541   0.17350358019999998
# Epoch:  9998  individuals:  200  best fitness:  0.4541   0.1682241124
#
# Calls 29645649
# Epoch:  9999  individuals:  200  best fitness:  0.4541   0.1737133454
# Epoch:  9999  individuals:  200  best fitness:  0.4541   0.1682355675
#
# Calls 29648813
# Epoch:  10000  individuals:  200  best fitness:  0.4541   0.19455678699999998
# Epoch:  10000  individuals:  200  best fitness:  0.4541   0.170571458
#
# Calls 29651976
# 45.41% ...
# 45.41% ...
#
# Calls 29651976
