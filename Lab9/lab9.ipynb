# %% [markdown]
# Copyright **`(c)`** 2023 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free for personal or classroom use; see [`LICENSE.md`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %% [markdown]
# # LAB9
#
# Write a local-search algorithm (eg. an EA) able to solve the *Problem* instances 1, 2, 5, and 10 on a 1000-loci genomes, using a minimum number of fitness calls. That's all.
#
# ### Deadlines:
#
# * Submission: Sunday, December 3 ([CET](https://www.timeanddate.com/time/zones/cet))
# * Reviews: Sunday, December 10 ([CET](https://www.timeanddate.com/time/zones/cet))
#
# Notes:
#
# * Reviews will be assigned  on Monday, December 4
# * You need to commit in order to be selected as a reviewer (ie. better to commit an empty work than not to commit)

# %%
from random import choices, random, randint
from queue import PriorityQueue
import numpy as np
# %pip install sortedcontainers
from sortedcontainers import SortedList

import lab9_lib
# Out:
# Requirement already satisfied: sortedcontainers in c:\users\vicin\desktop\polito\compint\venv\lib\site-packages (2.4.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# # Utils

# %%
def print_ind(ind):
    return f"{''.join(str(g) for g in ind)}"

def _mutate(a, prob: float):
    if random()<prob:
        return 1-a
    else:
        return a
    
def _mutation_mask(a,b):
    if a!=b:
        return b
    else:
        return -1
    
def _reapply_mutation(a,b):
    if a==-1:
        return b
    else:
        return a
    
def _crossover(a, b):
    if random()>0.5:
        return a
    else:
        return b
    
def gen_population(start_population:int, fitness:callable):
    population=SortedList(key=lambda e: -e[0])
    for i in range(start_population):
        ind=choices([0, 1], k=1000)
        fit=fitness(ind)
        population.add([fit,ind])
    return population

def print_population(population, verbose: bool):
    if not verbose:
        return
    for i in population:
        print(f"{i[0]:.2%} {print_ind(i[1])}")
    
gene_prob=[0 for _ in range(1000)]


mutate=np.vectorize(_mutate)
mutation_mask=np.vectorize(_mutation_mask)
crossover=np.vectorize(_crossover)

# %% [markdown]
# # Absolute Perfect Solution

# %%
def absolute_perfect_solution():
    return [1 for i in range(0,50)]

# %% [markdown]
# # Just Mutation
#
# Basically kills some individuals, mutate some others (and puts back both the original and the new one) \
# With: \
# Mutation(100, 0.1,0.5,0.1,fitness, verbose=False)
# - Problem 2: 96-100%
# - Problem 5: 75-80%
# - Problem 10: 70-80%

# %%
class Mutation():
    def __init__(self, start_population: int, kill_perc: float, mut_prob: float, gene_mut_prob:float, fitness: callable , with_removal:bool=False, verbose:bool=False, max_population:int=1000):
        self.population=gen_population(start_population, fitness)
        self.mut_prob=mut_prob
        self.gene_mut_prob=gene_mut_prob
        self.kill_perc=kill_perc
        self.epochs=0
        self.verbose=verbose
        self.fitness=fitness
        self.with_removal=with_removal
        self.max_population=max_population
        
        print_population(self.population, self.verbose)

    def step(self):
        global mutate
        
        self.epochs+=1

        ### KILL ###
        kill_population(self.population, self.kill_perc, self.max_population)
        
        ### MUTATE ###
        mutate_population(self.population, self.mut_prob, self.gene_mut_prob, self.fitness, self.with_removal)
                    #print(f"After: {i[0]:.2%} {print_ind(i[1])}")
        print("Epoch: ", self.epochs," individuals: ", len(self.population), " best fitness: ", self.best[0])
        #print(print_ind(self.best[1]))
        print_population(self.population, self.verbose)
    
    @property
    def best(self):
        return self.population[0]
    
def kill_population(population:list, kill_perc:float, max_pop=None):
    to_remove=int(len(population)*kill_perc)

    for _ in range(to_remove):
        population.pop()
    if max_pop!=None:
        while(len(population)>max_pop):
            population.pop()
            
        
    
def mutate_population(population,  population_sub:list, mut_prob: float, gene_mut_prob:float, fitness: callable , with_removal:bool=False):
    global gene_prob
    mutations=0
    for i in population_sub:
        #prob=(1 - (i[0]/100)) * mut_prob 
        prob_ind=[0 for _ in range(1000)]
        prob=mut_prob
        if(random()<prob):
            t=mutate(i[1], gene_mut_prob*(1-i[0]))
            t_fit=fitness(t)
            if(with_removal):
                population.remove(i)
            population.add([t_fit,t.tolist()])
            mutations+=1

# %% [markdown]
# # Crossover
#
# With random crossover it seems mutation gives better solutions \
#
# With this setting in can reach 100% of fitness in a range o
# cross=Crossover(50, 0.1, 5, .6, .5, fitness, verbose=False, with_removal=True)
# for _ in range(10000):
#     cross.step()

# %%
class Crossover():
    def __init__(self, start_population: int, kill_perc: float, offspring: int, mut_prob: float, gene_mut_prob:float, fitness: callable ,max_population:int=1000, with_removal:bool=False, verbose:bool=False):
        self.population=gen_population(start_population, fitness)
        self.kill_perc=kill_perc
        self.offspring=offspring
        self.mut_prob=mut_prob
        self.gene_mut_prob=gene_mut_prob
        self.fitness=fitness
        self.with_removal=with_removal
        self.verbose=verbose
        self.max_population=max_population
        self.epochs=0

        print_population(self.population, self.verbose)

    def step(self, elite_threshold=0.2, losers_pool=None, max_loser=600):
        global mutate, crossover, loser_population
        
        self.epochs+=1

        
        elite=int(elite_threshold*len(self.population))

        n_couples=int(0.5*elite*0.5)

        

        for _ in range(n_couples):
            crossover_population_by_difference(self.population, self.population, self.offspring, self.fitness)

        
        mutate_population(self.population, self.population[elite+1:], self.mut_prob, self.gene_mut_prob,self.fitness, self.with_removal)
        
        if losers_pool is None:
            kill_population(self.population, self.kill_perc,self.max_population)
        else:
            loser_population(self.population, losers_pool, self.kill_perc,self.max_population, max_loser)

        print("Epoch: ", self.epochs," individuals: ", len(self.population), " best fitness: ", self.best[0], " ",self.population[-1][0])
        #print(print_ind(self.best[1]))
        print_population(self.population, self.verbose)
    @property
    def best(self):
        return self.population[0]
    
    
    
def inject_new_individuals(population:SortedList, fitness, n=5):
    for _ in range(n):
        ind=choices([0, 1], k=1000)
        fit=fitness(ind)
        population.add([fit,ind])
    
def crossover_population(population_sub, population,offspring, fitness):
    #selected=[0 for _ in population]
    #print("Selected len: ", len(selected), " population: ", len(population))

    p1=0
    p2=0
    #while(True):
    p1=randint(0,len(population_sub)-1)
    p2=randint(0,len(population_sub)-1)
        # print("P1: ",p1," P2: ",p2, len(population))
        # if p2!=p1 and (selected[p1]==0) and (selected[p2]==0):
        #     break
    #selected[p1]=1
    #selected[p2]=1

    parent1=population_sub[p1]
    parent2=population_sub[p2]

    for _ in range(offspring):
        ind=crossover(parent1[1],parent2[1]).tolist()
        fit=fitness(ind)
        if ind!= parent1[1] and ind != parent2[1]:
            population.add([fit,ind])

def crossover_population_by_difference(population_sub, population,offspring, fitness):
    #selected=[0 for _ in population]
    #print("Selected len: ", len(selected), " population: ", len(population))

    p1=0
    p2=0
    #while(True):
    p1=randint(0,len(population_sub)-1)
    p2=0
        # print("P1: ",p1," P2: ",p2, len(population))
        # if p2!=p1 and (selected[p1]==0) and (selected[p2]==0):
        #     break
    #selected[p1]=1
    #selected[p2]=1
    parent1=population_sub[p1]
    parent2=population_sub[p2]
    maxent=0
    for i in range(len(population_sub)):
        temp=population_sub[i]
        e=entropy(parent1[1],temp[1])
        
        if e>maxent:
            maxent=e
            parent2=temp

    #print(f"{print_ind(temp[1])}, {e}")

    for _ in range(offspring):
        ind=crossover(parent1[1],parent2[1]).tolist()
        if ind!= parent1[1] and ind != parent2[1]:
            fit=fitness(ind)
            population.add([fit,ind])

def entropy(ind1, ind2):
    return sum([1 for i in range(len(ind1)) if ind1[i]!=ind2[1]])

# %%
def remove_similar(population:SortedList):
    individuals=[]
    for i in population:
        if i in individuals:
            population.remove(i)
        else:
            individuals.append(i)

# %% [markdown]
# # Phenotype Study

# %% [markdown]
# # Testing Solution
#
# Crossover + Islands + Mass Extinctions:
# start ind=50
# kill_perc=0.5
# offsprings=15
# mutation_prob= 0.8
# gene_mutation_prob = .5
# with_removal=False
# max_population=200
#
# Problem 2: 100% in 1.3M fitness calls
# Problem 5: 100% in 1.5M fitness calls

# %%
fitness = lab9_lib.make_problem(10)

#mut=Mutation(100, 0,0.1,.2,fitness, verbose=False, max_population=500)
#for i in range(10000):
#    mut.step()
#    if ((i+1)%40) == 0:
#        inject_new_individuals(cross.population,fitness,30)
# best=mut.best
# print(f"{best[0]:.2%} {print_ind(best[1])}")

losers_pool=SortedList()
cross1=Crossover(50, 0.5, 15, .8, .5, fitness, verbose=False, with_removal=False,max_population=200)
cross2=Crossover(50, 0.5, 15, .8, .5, fitness, verbose=False, with_removal=False,max_population=200)


for i in range(10000):
    cross1.step(.2)
    cross2.step(.2)
    
    # if i%40==0:
    #    if len(losers_pool)>20:
    #        cross1.population.update(losers_pool[:])
    #        cross2.population.update(losers_pool[:])
    #    kill_population(losers_pool, 1,100)
    #    inject_new_individuals(cross2.population,fitness, 30)
    #    inject_new_individuals(cross1.population,fitness, 30)
    #    print(len(losers_pool))
    remove_similar(cross1.population)
    remove_similar(cross2.population)

    

    #mutate_population(losers_pool,losers_pool, 0.8,.5,fitness)
    #kill_population(losers_pool, 0,100)
    #remove_similar(losers_pool)

    # if len(cross1.population)>5 and len(cross2.population)>5:
    #     cross1.population.update(cross2.population[:5])
    #     cross2.population.update(cross1.population[:5])

    if (i+1 )% 40==0:
        kill_population(cross1.population, 0.9,200)
        kill_population(cross2.population, 0.9,200)
        inject_new_individuals(cross2.population,fitness, 30)
        inject_new_individuals(cross1.population,fitness, 30)
        cross1.population.update(cross2.population[:5])
        cross2.population.update(cross1.population[:5])
    
    print(f"\nCalls {fitness.calls}")
    if cross1.best[0]==1.0 or cross2.best[0]==1.0:
        break


best1=cross1.best
best2=cross2.best

print(f"{best1[0]:.2%} {print_ind(best1[1])}")
print(f"{best2[0]:.2%} {print_ind(best2[1])}")

print(f"\nCalls {fitness.calls}")
# Out:
# Epoch:  1  individuals:  68  best fitness:  0.194691142   0.051791113691
# Epoch:  1  individuals:  68  best fitness:  0.1621367027   0.051922466688
#
# Calls 272
# Epoch:  2  individuals:  100  best fitness:  0.198468009   0.052590124896
# Epoch:  2  individuals:  93  best fitness:  0.206226041   0.053122468129
#
# Calls 520
# Epoch:  3  individuals:  148  best fitness:  0.202335798   0.053356790006
# Epoch:  3  individuals:  130  best fitness:  0.21805568399999997   0.053714689120000006
#
# Calls 881
# Epoch:  4  individuals:  200  best fitness:  0.214566906   0.054344566829999996
# Epoch:  4  individuals:  187  best fitness:  0.21805568399999997   0.054445792507999996
#
# Calls 1404
# Epoch:  5  individuals:  200  best fitness:  0.221913566   0.057925577898
# Epoch:  5  individuals:  200  best fitness:  0.21805568399999997   0.056023448005999996
#
# Calls 2168
# Epoch:  6  individuals:  200  best fitness:  0.221913566   0.10024455829
# Epoch:  6  individuals:  200  best fitness:  0.221813806   0.10022789017
#
# Calls 2940
# Epoch:  7  individuals:  200  best fitness:  0.221913566   0.10400014007
# Epoch:  7  individuals:  200  best fitness:  0.221813806   0.10411346711
#
# Calls 3719
# Epoch:  8  individuals:  200  best fitness:  0.221913566   0.10466667907
# Epoch:  8  individuals:  200  best fitness:  0.221813806   0.10600033461
#
# Calls 4520
# Epoch:  9  individuals:  200  best fitness:  0.221913566   0.10602456796
# Epoch:  9  individuals:  200  best fitness:  0.221813806   0.10779013485
#
# Calls 5308
# Epoch:  10  individuals:  200  best fitness:  0.221913566   0.10789345796000001
# Epoch:  10  individuals:  200  best fitness:  0.221813806   0.10811255684
#
# Calls 6103
# Epoch:  11  individuals:  200  best fitness:  0.221914809   0.10803372228000001
# Epoch:  11  individuals:  200  best fitness:  0.27435595999999995   0.10967913584
#
# Calls 6899
# Epoch:  12  individuals:  200  best fitness:  0.221914809   0.10978123675000001
# Epoch:  12  individuals:  200  best fitness:  0.27435595999999995   0.10981446049
#
# Calls 7708
# Epoch:  13  individuals:  200  best fitness:  0.221914809   0.11000112257000001
# Epoch:  13  individuals:  200  best fitness:  0.27435595999999995   0.10990334573
#
# Calls 8511
# Epoch:  14  individuals:  200  best fitness:  0.221914809   0.11166911379
# Epoch:  14  individuals:  200  best fitness:  0.27435595999999995   0.11157237906
#
# Calls 9309
# Epoch:  15  individuals:  200  best fitness:  0.221914809   0.11181245708
# Epoch:  15  individuals:  200  best fitness:  0.27435595999999995   0.11178005722
#
# Calls 10119
# Epoch:  16  individuals:  200  best fitness:  0.221914809   0.11212344482
# Epoch:  16  individuals:  200  best fitness:  0.27435595999999995   0.11200023584999999
#
# Calls 10914
# Epoch:  17  individuals:  200  best fitness:  0.221914809   0.11356934898
# Epoch:  17  individuals:  200  best fitness:  0.27435595999999995   0.11346824475
#
# Calls 11716
# Epoch:  18  individuals:  200  best fitness:  0.221914809   0.11368903458
# Epoch:  18  individuals:  200  best fitness:  0.27435597   0.11369237808
#
# Calls 12511
# Epoch:  19  individuals:  200  best fitness:  0.226166796   0.11383334573000001
# Epoch:  19  individuals:  200  best fitness:  0.27435597   0.11400445616
#
# Calls 13298
# Epoch:  20  individuals:  200  best fitness:  0.226166796   0.11412234584
# Epoch:  20  individuals:  200  best fitness:  0.27435597   0.11412235817
#
# Calls 14086
# Epoch:  21  individuals:  200  best fitness:  0.226166796   0.11591114829
# Epoch:  21  individuals:  200  best fitness:  0.27435597   0.11558146816999999
#
# Calls 14887
# Epoch:  22  individuals:  200  best fitness:  0.226166796   0.11782238009
# Epoch:  22  individuals:  200  best fitness:  0.27435597   0.11766825595000001
#
# Calls 15682
# Epoch:  23  individuals:  200  best fitness:  0.226166796   0.1474455684
# Epoch:  23  individuals:  200  best fitness:  0.27435597   0.15034449419999998
#
# Calls 16485
# Epoch:  24  individuals:  200  best fitness:  0.226256684   0.1503569005
# Epoch:  24  individuals:  200  best fitness:  0.27445606   0.1532333453
#
# Calls 17279
# Epoch:  25  individuals:  200  best fitness:  0.226256684   0.153234472
# Epoch:  25  individuals:  200  best fitness:  0.27455608000000004   0.15622234510000002
#
# Calls 18068
# Epoch:  26  individuals:  200  best fitness:  0.226256684   0.1532455797
# Epoch:  26  individuals:  200  best fitness:  0.27455608000000004   0.1590345589
#
# Calls 18879
# Epoch:  27  individuals:  200  best fitness:  0.226256684   0.1533555684
# Epoch:  27  individuals:  200  best fitness:  0.27455699   0.1618935585
#
# Calls 19673
# Epoch:  28  individuals:  200  best fitness:  0.226256684   0.15356691179999998
# Epoch:  28  individuals:  200  best fitness:  0.27455709   0.1620034951
#
# Calls 20435
# Epoch:  29  individuals:  200  best fitness:  0.226256684   0.15612233420000002
# Epoch:  29  individuals:  200  best fitness:  0.27455709   0.1647834607
#
# Calls 21190
# Epoch:  30  individuals:  200  best fitness:  0.226256684   0.1561345942
# Epoch:  30  individuals:  200  best fitness:  0.31815249999999995   0.16480269290000002
#
# Calls 21950
# Epoch:  31  individuals:  200  best fitness:  0.25468006   0.1561445684
# Epoch:  31  individuals:  200  best fitness:  0.31815249999999995   0.1648044586
#
# Calls 22719
# Epoch:  32  individuals:  200  best fitness:  0.25468006   0.1562334643
# Epoch:  32  individuals:  200  best fitness:  0.31815249999999995   0.16480456100000002
#
# Calls 23491
# Epoch:  33  individuals:  200  best fitness:  0.25468006   0.1562558917
# Epoch:  33  individuals:  200  best fitness:  0.31815249999999995   0.164804572
#
# Calls 24287
# Epoch:  34  individuals:  200  best fitness:  0.25468006   0.1564680128
# Epoch:  34  individuals:  200  best fitness:  0.31815249999999995   0.16489266989999998
#
# Calls 25113
# Epoch:  35  individuals:  200  best fitness:  0.25468006   0.1590112416
# Epoch:  35  individuals:  200  best fitness:  0.31815249999999995   0.1649001254
#
# Calls 25896
# Epoch:  36  individuals:  200  best fitness:  0.25468006   0.1590133465
# Epoch:  36  individuals:  200  best fitness:  0.31815249999999995   0.1649035861
#
# Calls 26650
# Epoch:  37  individuals:  200  best fitness:  0.25468006   0.1590237809
# Epoch:  37  individuals:  200  best fitness:  0.31815249999999995   0.16492779049999998
#
# Calls 27433
# Epoch:  38  individuals:  200  best fitness:  0.25468006   0.1591245695
# Epoch:  38  individuals:  200  best fitness:  0.31815249999999995   0.1650011243
#
# Calls 28216
# Epoch:  39  individuals:  200  best fitness:  0.25468006   0.1591257817
# Epoch:  39  individuals:  200  best fitness:  0.31815249999999995   0.1650236017
#
# Calls 28996
# Epoch:  40  individuals:  200  best fitness:  0.25468006   0.1591334473
# Epoch:  40  individuals:  200  best fitness:  0.31815249999999995   0.16512457
#
# Calls 29844
# Epoch:  41  individuals:  73  best fitness:  0.31815249999999995   0.052902478006
# Epoch:  41  individuals:  72  best fitness:  0.31815249999999995   0.052890135574
#
# Calls 30023
# Epoch:  42  individuals:  100  best fitness:  0.31815249999999995   0.054558916922
# Epoch:  42  individuals:  101  best fitness:  0.31815249999999995   0.054022390052
#
# Calls 30282
# Epoch:  43  individuals:  147  best fitness:  0.31815249999999995   0.055234590017
# Epoch:  43  individuals:  138  best fitness:  0.31815249999999995   0.054347236728
#
# Calls 30653
# Epoch:  44  individuals:  200  best fitness:  0.31815249999999995   0.055800112241000004
# Epoch:  44  individuals:  198  best fitness:  0.31815249999999995   0.054889458245
#
# Calls 31189
# Epoch:  45  individuals:  200  best fitness:  0.31815249999999995   0.10212344808
# Epoch:  45  individuals:  200  best fitness:  0.32425740000000003   0.057681224481
#
# Calls 31962
# Epoch:  46  individuals:  200  best fitness:  0.31815249999999995   0.10590003695
# Epoch:  46  individuals:  200  best fitness:  0.32425740000000003   0.10212346702
#
# Calls 32731
# Epoch:  47  individuals:  200  best fitness:  0.31815249999999995   0.10779035587
# Epoch:  47  individuals:  200  best fitness:  0.32425740000000003   0.10589223562
#
# Calls 33537
# Epoch:  48  individuals:  200  best fitness:  0.31815249999999995   0.10789445684
# Epoch:  48  individuals:  200  best fitness:  0.32425740000000003   0.10622334505
#
# Calls 34310
# Epoch:  49  individuals:  200  best fitness:  0.31815249999999995   0.108011158
# Epoch:  49  individuals:  200  best fitness:  0.32425740000000003   0.10779114572000001
#
# Calls 35110
# Epoch:  50  individuals:  200  best fitness:  0.31815249999999995   0.109669224
# Epoch:  50  individuals:  200  best fitness:  0.32425740000000003   0.10801334621
#
# Calls 35909
# Epoch:  51  individuals:  200  best fitness:  0.31815249999999995   0.10971122341999999
# Epoch:  51  individuals:  200  best fitness:  0.32425740000000003   0.10977896695
#
# Calls 36677
# Epoch:  52  individuals:  200  best fitness:  0.31815249999999995   0.11000111261
# Epoch:  52  individuals:  200  best fitness:  0.32425740000000003   0.10991245684
#
# Calls 37489
# Epoch:  53  individuals:  200  best fitness:  0.31815249999999995   0.11158901607999999
# Epoch:  53  individuals:  200  best fitness:  0.32425740000000003   0.11033356698999999
#
# Calls 38274
# Epoch:  54  individuals:  200  best fitness:  0.31815249999999995   0.11170489028
# Epoch:  54  individuals:  200  best fitness:  0.32425740000000003   0.11190456786
#
# Calls 39069
# Epoch:  55  individuals:  200  best fitness:  0.31815249999999995   0.11190346796
# Epoch:  55  individuals:  200  best fitness:  0.32425740000000003   0.11212344453
#
# Calls 39876
# Epoch:  56  individuals:  200  best fitness:  0.31815249999999995   0.11537039029
# Epoch:  56  individuals:  200  best fitness:  0.32425740000000003   0.11400123573000001
#
# Calls 40664
# Epoch:  57  individuals:  200  best fitness:  0.31815249999999995   0.1503667916
# Epoch:  57  individuals:  200  best fitness:  0.32425740000000003   0.11567903694000001
#
# Calls 41409
# Epoch:  58  individuals:  200  best fitness:  0.31815249999999995   0.15611125139999998
# Epoch:  58  individuals:  200  best fitness:  0.32425740000000003   0.153256802
#
# Calls 42159
# Epoch:  59  individuals:  200  best fitness:  0.31815249999999995   0.1562455586
# Epoch:  59  individuals:  200  best fitness:  0.32425740000000003   0.1533445739
#
# Calls 42842
# Epoch:  60  individuals:  200  best fitness:  0.372413   0.1590122587
# Epoch:  60  individuals:  200  best fitness:  0.32425740000000003   0.1562558907
#
# Calls 43600
# Epoch:  61  individuals:  200  best fitness:  0.372433   0.15903345659999998
# Epoch:  61  individuals:  200  best fitness:  0.32425740000000003   0.1590002564
#
# Calls 44335
# Epoch:  62  individuals:  200  best fitness:  0.372535   0.1619245563
# Epoch:  62  individuals:  200  best fitness:  0.32425740000000003   0.1591124576
#
# Calls 45066
# Epoch:  63  individuals:  200  best fitness:  0.372535   0.210111504
# Epoch:  63  individuals:  200  best fitness:  0.32425740000000003   0.1592344794
#
# Calls 45712
# Epoch:  64  individuals:  200  best fitness:  0.372535   0.210112515
# Epoch:  64  individuals:  200  best fitness:  0.3242674   0.1619004794
#
# Calls 46376
# Epoch:  65  individuals:  200  best fitness:  0.372535   0.26411403
# Epoch:  65  individuals:  200  best fitness:  0.3242674   0.1619023916
#
# Calls 47056
# Epoch:  66  individuals:  200  best fitness:  0.372535   0.26411513999999997
# Epoch:  66  individuals:  200  best fitness:  0.3242674   0.1621237794
#
# Calls 47654
# Epoch:  67  individuals:  200  best fitness:  0.372535   0.26411524
# Epoch:  67  individuals:  200  best fitness:  0.3242674   0.1648001151
#
# Calls 48239
# Epoch:  68  individuals:  193  best fitness:  0.372535   0.26411525
# Epoch:  68  individuals:  200  best fitness:  0.3242674   0.1649001675
#
# Calls 48818
# Epoch:  69  individuals:  200  best fitness:  0.372535   0.31814030000000004
# Epoch:  69  individuals:  200  best fitness:  0.3242674   0.210111563
#
# Calls 49435
# Epoch:  70  individuals:  200  best fitness:  0.372535   0.3181435
# Epoch:  70  individuals:  200  best fitness:  0.3242674   0.214001674
#
# Calls 49971
# Epoch:  71  individuals:  199  best fitness:  0.372535   0.3181524
# Epoch:  71  individuals:  200  best fitness:  0.3242674   0.217902342
#
# Calls 50461
# Epoch:  72  individuals:  162  best fitness:  0.372535   0.31815249999999995
# Epoch:  72  individuals:  175  best fitness:  0.3242674   0.26901574
#
# Calls 50824
# Epoch:  73  individuals:  138  best fitness:  0.372535   0.3181533
# Epoch:  73  individuals:  183  best fitness:  0.3242685   0.26901575
#
# Calls 51200
# Epoch:  74  individuals:  127  best fitness:  0.372535   0.31815350000000003
# Epoch:  74  individuals:  194  best fitness:  0.3242685   0.26902573999999996
#
# Calls 51588
# Epoch:  75  individuals:  113  best fitness:  0.372535   0.31815350000000003
# Epoch:  75  individuals:  185  best fitness:  0.3242685   0.26902674000000004
#
# Calls 51935
# Epoch:  76  individuals:  107  best fitness:  0.372535   0.31815350000000003
# Epoch:  76  individuals:  185  best fitness:  0.3242685   0.26902674000000004
#
# Calls 52279
# Epoch:  77  individuals:  89  best fitness:  0.372545   0.3182534
# Epoch:  77  individuals:  178  best fitness:  0.3242685   0.26902675
#
# Calls 52577
# Epoch:  78  individuals:  83  best fitness:  0.372545   0.372425
# Epoch:  78  individuals:  159  best fitness:  0.3242685   0.26902685000000004
#
# Calls 52840
# Epoch:  79  individuals:  79  best fitness:  0.372545   0.37252300000000005
# Epoch:  79  individuals:  181  best fitness:  0.3242685   0.10992445684
#
# Calls 53159
# Epoch:  80  individuals:  67  best fitness:  0.372545   0.372524
# Epoch:  80  individuals:  180  best fitness:  0.3242685   0.26903675
#
# Calls 53497
# Epoch:  81  individuals:  59  best fitness:  0.372545   0.05358233348599999
# Epoch:  81  individuals:  70  best fitness:  0.372545   0.052789234596999995
#
# Calls 53662
# Epoch:  82  individuals:  71  best fitness:  0.372545   0.054789146680999996
# Epoch:  82  individuals:  95  best fitness:  0.372545   0.053713333628
#
# Calls 53872
# Epoch:  83  individuals:  100  best fitness:  0.372545   0.05558022350399999
# Epoch:  83  individuals:  136  best fitness:  0.372545   0.05445001124399999
#
# Calls 54179
# Epoch:  84  individuals:  148  best fitness:  0.372545   0.055692456708
# Epoch:  84  individuals:  189  best fitness:  0.372545   0.054491790027999996
#
# Calls 54617
# Epoch:  85  individuals:  200  best fitness:  0.372545   0.056179013386999994
# Epoch:  85  individuals:  200  best fitness:  0.372545   0.056578926031
#
# Calls 55281
# Epoch:  86  individuals:  200  best fitness:  0.372545   0.062578925786
# Epoch:  86  individuals:  200  best fitness:  0.372545   0.09834467820000001
#
# Calls 56071
# Epoch:  87  individuals:  200  best fitness:  0.372545   0.10402346687
# Epoch:  87  individuals:  200  best fitness:  0.372545   0.10413445838999999
#
# Calls 56866
# Epoch:  88  individuals:  200  best fitness:  0.372545   0.10590013706000001
# Epoch:  88  individuals:  200  best fitness:  0.372545   0.10600012552
#
# Calls 57658
# Epoch:  89  individuals:  200  best fitness:  0.372545   0.10611556818
# Epoch:  89  individuals:  200  best fitness:  0.372545   0.10781225578
#
# Calls 58432
# Epoch:  90  individuals:  200  best fitness:  0.372545   0.10780123736
# Epoch:  90  individuals:  200  best fitness:  0.372545   0.10800223642000001
#
# Calls 59246
# Epoch:  91  individuals:  200  best fitness:  0.372545   0.10793672449
# Epoch:  91  individuals:  200  best fitness:  0.372545   0.10971256788
#
# Calls 60043
# Epoch:  92  individuals:  200  best fitness:  0.372545   0.10968913714999999
# Epoch:  92  individuals:  200  best fitness:  0.372545   0.11012446896
#
# Calls 60840
# Epoch:  93  individuals:  200  best fitness:  0.372545   0.10989012483999999
# Epoch:  93  individuals:  200  best fitness:  0.372545   0.11167333484
#
# Calls 61571
# Epoch:  94  individuals:  200  best fitness:  0.372545   0.11022336710000001
# Epoch:  94  individuals:  200  best fitness:  0.372545   0.11171255674
#
# Calls 62285
# Epoch:  95  individuals:  200  best fitness:  0.372545   0.11171233475
# Epoch:  95  individuals:  200  best fitness:  0.372635   0.11359011673000001
#
# Calls 63094
# Epoch:  96  individuals:  200  best fitness:  0.372545   0.11200023485
# Epoch:  96  individuals:  200  best fitness:  0.37264600000000003   0.11592356899
#
# Calls 63873
# Epoch:  97  individuals:  200  best fitness:  0.372556   0.11412455683
# Epoch:  97  individuals:  200  best fitness:  0.37264600000000003   0.15044556890000002
#
# Calls 64620
# Epoch:  98  individuals:  200  best fitness:  0.372556   0.1504478048
# Epoch:  98  individuals:  200  best fitness:  0.372647   0.1591235808
#
# Calls 65378
# Epoch:  99  individuals:  200  best fitness:  0.372556   0.1561257923
# Epoch:  99  individuals:  200  best fitness:  0.372647   0.170571292
#
# Calls 66094
# Epoch:  100  individuals:  200  best fitness:  0.372556   0.15900015439999998
# Epoch:  100  individuals:  200  best fitness:  0.372647   0.26411624
#
# Calls 66805
# Epoch:  101  individuals:  200  best fitness:  0.372645   0.1590001656
# Epoch:  101  individuals:  200  best fitness:  0.372647   0.3181545
#
# Calls 67466
# Epoch:  102  individuals:  200  best fitness:  0.372656   0.1620135795
# Epoch:  102  individuals:  195  best fitness:  0.372647   0.3181546
#
# Calls 68053
# Epoch:  103  individuals:  200  best fitness:  0.372656   0.198455718
# Epoch:  103  individuals:  177  best fitness:  0.372647   0.3181636
#
# Calls 68542
# Epoch:  104  individuals:  200  best fitness:  0.372656   0.210111625
# Epoch:  104  individuals:  170  best fitness:  0.372647   0.31816449999999996
#
# Calls 69031
# Epoch:  105  individuals:  200  best fitness:  0.372656   0.217901927
# Epoch:  105  individuals:  174  best fitness:  0.372647   0.1590278016
#
# Calls 69583
# Epoch:  106  individuals:  200  best fitness:  0.372656   0.26411656
# Epoch:  106  individuals:  166  best fitness:  0.372647   0.3181646
#
# Calls 70040
# Epoch:  107  individuals:  200  best fitness:  0.372656   0.26412556
# Epoch:  107  individuals:  180  best fitness:  0.372647   0.3181546
#
# Calls 70507
# Epoch:  108  individuals:  200  best fitness:  0.372656   0.3181546
# Epoch:  108  individuals:  169  best fitness:  0.372647   0.31816469999999997
#
# Calls 70945
# Epoch:  109  individuals:  199  best fitness:  0.372656   0.3181546
# Epoch:  109  individuals:  127  best fitness:  0.372647   0.372436
#
# Calls 71296
# Epoch:  110  individuals:  200  best fitness:  0.372656   0.31815550000000004
# Epoch:  110  individuals:  120  best fitness:  0.372647   0.372526
#
# Calls 71670
# Epoch:  111  individuals:  200  best fitness:  0.372656   0.3181556
# Epoch:  111  individuals:  125  best fitness:  0.372647   0.31816469999999997
#
# Calls 72090
# Epoch:  112  individuals:  185  best fitness:  0.372656   0.3181646
# Epoch:  112  individuals:  148  best fitness:  0.372647   0.372534
#
# Calls 72478
# Epoch:  113  individuals:  178  best fitness:  0.372656   0.3181646
# Epoch:  113  individuals:  149  best fitness:  0.372647   0.3181637
#
# Calls 72854
# Epoch:  114  individuals:  183  best fitness:  0.372656   0.3181646
# Epoch:  114  individuals:  154  best fitness:  0.372647   0.3181646
#
# Calls 73248
# Epoch:  115  individuals:  177  best fitness:  0.372656   0.3181646
# Epoch:  115  individuals:  153  best fitness:  0.372647   0.372535
#
# Calls 73622
# Epoch:  116  individuals:  173  best fitness:  0.372656   0.3181646
# Epoch:  116  individuals:  136  best fitness:  0.372647   0.372544
#
# Calls 73966
# Epoch:  117  individuals:  171  best fitness:  0.372656   0.3181655
# Epoch:  117  individuals:  135  best fitness:  0.372647   0.372545
#
# Calls 74319
# Epoch:  118  individuals:  169  best fitness:  0.372656   0.1561244506
# Epoch:  118  individuals:  127  best fitness:  0.372647   0.31816469999999997
#
# Calls 74661
# Epoch:  119  individuals:  186  best fitness:  0.372656   0.3181655
# Epoch:  119  individuals:  98  best fitness:  0.372647   0.372546
#
# Calls 74978
# Epoch:  120  individuals:  188  best fitness:  0.372656   0.31815550000000004
# Epoch:  120  individuals:  112  best fitness:  0.372647   0.31816469999999997
#
# Calls 75400
# Epoch:  121  individuals:  61  best fitness:  0.372656   0.052801800028
# Epoch:  121  individuals:  62  best fitness:  0.372656   0.052906778021
#
# Calls 75549
# Epoch:  122  individuals:  53  best fitness:  0.372656   0.056560125785
# Epoch:  122  individuals:  73  best fitness:  0.372656   0.055635791362999995
#
# Calls 75686
# Epoch:  123  individuals:  69  best fitness:  0.372656   0.054624579027
# Epoch:  123  individuals:  95  best fitness:  0.37274599999999997   0.056782366818
#
# Calls 75895
# Epoch:  124  individuals:  95  best fitness:  0.372656   0.054124566783
# Epoch:  124  individuals:  122  best fitness:  0.372757   0.057892336711
#
# Calls 76171
# Epoch:  125  individuals:  120  best fitness:  0.372656   0.055822234453
# Epoch:  125  individuals:  151  best fitness:  0.372757   0.1040013459
#
# Calls 76505
# Epoch:  126  individuals:  158  best fitness:  0.372656   0.055911133563999994
# Epoch:  126  individuals:  172  best fitness:  0.372757   0.10423556696
#
# Calls 76923
# Epoch:  127  individuals:  200  best fitness:  0.372656   0.056560125785
# Epoch:  127  individuals:  187  best fitness:  0.372757   0.10591333486
#
# Calls 77390
# Epoch:  128  individuals:  200  best fitness:  0.372656   0.09668922349
# Epoch:  128  individuals:  200  best fitness:  0.372758   0.10778891210000001
#
# Calls 77971
# Epoch:  129  individuals:  200  best fitness:  0.372656   0.10401345016
# Epoch:  129  individuals:  200  best fitness:  0.372758   0.11002446862
#
# Calls 78726
# Epoch:  130  individuals:  200  best fitness:  0.372656   0.10601256799
# Epoch:  130  individuals:  200  best fitness:  0.372758   0.26411648000000004
#
# Calls 79474
# Epoch:  131  individuals:  200  best fitness:  0.372755   0.10790113596
# Epoch:  131  individuals:  200  best fitness:  0.372758   0.3181656
#
# Calls 80095
# Epoch:  132  individuals:  200  best fitness:  0.372755   0.10823345802
# Epoch:  132  individuals:  200  best fitness:  0.372758   0.3181747
#
# Calls 80760
# Epoch:  133  individuals:  200  best fitness:  0.372756   0.11180335675
# Epoch:  133  individuals:  183  best fitness:  0.372758   0.31817559999999995
#
# Calls 81292
# Epoch:  134  individuals:  200  best fitness:  0.372756   0.10968345684
# Epoch:  134  individuals:  175  best fitness:  0.372758   0.3181757
#
# Calls 81850
# Epoch:  135  individuals:  200  best fitness:  0.372756   0.11002233574999999
# Epoch:  135  individuals:  186  best fitness:  0.372758   0.3181658
#
# Calls 82401
# Epoch:  136  individuals:  200  best fitness:  0.372757   0.11201122701
# Epoch:  136  individuals:  200  best fitness:  0.372758   0.3181757
#
# Calls 83010
# Epoch:  137  individuals:  200  best fitness:  0.372757   0.11377936683999999
# Epoch:  137  individuals:  193  best fitness:  0.372758   0.3181757
#
# Calls 83574
# Epoch:  138  individuals:  200  best fitness:  0.372758   0.1533344588
# Epoch:  138  individuals:  200  best fitness:  0.372758   0.26411757
#
# Calls 84173
# Epoch:  139  individuals:  200  best fitness:  0.372758   0.15914457939999999
# Epoch:  139  individuals:  200  best fitness:  0.372758   0.31817559999999995
#
# Calls 84777
# Epoch:  140  individuals:  200  best fitness:  0.372758   0.10801123676999999
# Epoch:  140  individuals:  199  best fitness:  0.372758   0.3181757
#
# Calls 85320
# Epoch:  141  individuals:  200  best fitness:  0.372758   0.26411657000000005
# Epoch:  141  individuals:  200  best fitness:  0.372758   0.3181757
#
# Calls 85905
# Epoch:  142  individuals:  195  best fitness:  0.372758   0.3181657
# Epoch:  142  individuals:  193  best fitness:  0.372758   0.3181758
#
# Calls 86348
# Epoch:  143  individuals:  181  best fitness:  0.372758   0.31817559999999995
# Epoch:  143  individuals:  200  best fitness:  0.372758   0.3182657
#
# Calls 86866
# Epoch:  144  individuals:  144  best fitness:  0.372758   0.3181757
# Epoch:  144  individuals:  176  best fitness:  0.372758   0.372645
#
# Calls 87200
# Epoch:  145  individuals:  118  best fitness:  0.372758   0.3181757
# Epoch:  145  individuals:  194  best fitness:  0.372758   0.37264600000000003
#
# Calls 87553
# Epoch:  146  individuals:  141  best fitness:  0.372758   0.3181757
# Epoch:  146  individuals:  200  best fitness:  0.372758   0.372647
#
# Calls 87993
# Epoch:  147  individuals:  140  best fitness:  0.372758   0.3181758
# Epoch:  147  individuals:  200  best fitness:  0.372758   0.3181758
#
# Calls 88396
# Epoch:  148  individuals:  134  best fitness:  0.372758   0.3181758
# Epoch:  148  individuals:  200  best fitness:  0.372758   0.3181757
#
# Calls 88804
# Epoch:  149  individuals:  130  best fitness:  0.372758   0.372647
# Epoch:  149  individuals:  178  best fitness:  0.372758   0.3181758
#
# Calls 89143
# Epoch:  150  individuals:  123  best fitness:  0.372758   0.372647
# Epoch:  150  individuals:  186  best fitness:  0.372758   0.3181757
#
# Calls 89498
# Epoch:  151  individuals:  143  best fitness:  0.372758   0.3181658
# Epoch:  151  individuals:  154  best fitness:  0.372758   0.372656
#
# Calls 89827
# Epoch:  152  individuals:  153  best fitness:  0.372758   0.3181748
# Epoch:  152  individuals:  178  best fitness:  0.372758   0.10401368255
#
# Calls 90237
# Epoch:  153  individuals:  134  best fitness:  0.372758   0.37265499999999996
# Epoch:  153  individuals:  195  best fitness:  0.372758   0.10781556686
#
# Calls 90614
# Epoch:  154  individuals:  133  best fitness:  0.372758   0.37265499999999996
# Epoch:  154  individuals:  200  best fitness:  0.372758   0.3181747
#
# Calls 91053
# Epoch:  155  individuals:  135  best fitness:  0.372758   0.372656
# Epoch:  155  individuals:  200  best fitness:  0.372758   0.3181757
#
# Calls 91478
# Epoch:  156  individuals:  128  best fitness:  0.372758   0.372656
# Epoch:  156  individuals:  180  best fitness:  0.372758   0.3181757
#
# Calls 91823
# Epoch:  157  individuals:  122  best fitness:  0.372758   0.3181758
# Epoch:  157  individuals:  182  best fitness:  0.372758   0.3181657
#
# Calls 92181
# Epoch:  158  individuals:  127  best fitness:  0.372758   0.3181758
# Epoch:  158  individuals:  172  best fitness:  0.372758   0.3181757
#
# Calls 92529
# Epoch:  159  individuals:  128  best fitness:  0.372758   0.3181758
# Epoch:  159  individuals:  163  best fitness:  0.372758   0.3181758
#
# Calls 92859
# Epoch:  160  individuals:  121  best fitness:  0.372758   0.372656
# Epoch:  160  individuals:  183  best fitness:  0.372758   0.10636701193999999
#
# Calls 93278
# Epoch:  161  individuals:  65  best fitness:  0.372758   0.053780134919
# Epoch:  161  individuals:  67  best fitness:  0.372758   0.052933457118
#
# Calls 93444
# Epoch:  162  individuals:  94  best fitness:  0.372758   0.055011357023
# Epoch:  162  individuals:  94  best fitness:  0.372758   0.053823366805
#
# Calls 93691
# Epoch:  163  individuals:  135  best fitness:  0.372758   0.05523346793
# Epoch:  163  individuals:  130  best fitness:  0.372758   0.054744567928000004
#
# Calls 94032
# Epoch:  164  individuals:  196  best fitness:  0.372758   0.055603344524
# Epoch:  164  individuals:  188  best fitness:  0.372758   0.054826778245
#
# Calls 94535
# Epoch:  165  individuals:  200  best fitness:  0.372758   0.059044555826999995
# Epoch:  165  individuals:  200  best fitness:  0.372758   0.057134567917
#
# Calls 95275
# Epoch:  166  individuals:  200  best fitness:  0.372758   0.10412344509
# Epoch:  166  individuals:  200  best fitness:  0.372758   0.10056667899999999
#
# Calls 96072
# Epoch:  167  individuals:  200  best fitness:  0.372758   0.10611345785000001
# Epoch:  167  individuals:  200  best fitness:  0.372758   0.10411355649
#
# Calls 96872
# Epoch:  168  individuals:  200  best fitness:  0.372758   0.10782235676
# Epoch:  168  individuals:  200  best fitness:  0.372758   0.1060002382
#
# Calls 97660
# Epoch:  169  individuals:  200  best fitness:  0.372758   0.1080033426
# Epoch:  169  individuals:  200  best fitness:  0.372758   0.10613335578000001
#
# Calls 98453
# Epoch:  170  individuals:  200  best fitness:  0.372758   0.10971134931
# Epoch:  170  individuals:  200  best fitness:  0.372758   0.10790222943000001
#
# Calls 99236
# Epoch:  171  individuals:  200  best fitness:  0.372758   0.10993666931
# Epoch:  171  individuals:  200  best fitness:  0.372758   0.10801267916
#
# Calls 100003
# Epoch:  172  individuals:  200  best fitness:  0.372758   0.11167004704
# Epoch:  172  individuals:  200  best fitness:  0.372758   0.10811356676
#
# Calls 100773
# Epoch:  173  individuals:  200  best fitness:  0.372758   0.11179113946
# Epoch:  173  individuals:  200  best fitness:  0.372758   0.10980125929000001
#
# Calls 101529
# Epoch:  174  individuals:  200  best fitness:  0.372758   0.11367891858
# Epoch:  174  individuals:  200  best fitness:  0.372758   0.1100222404
#
# Calls 102336
# Epoch:  175  individuals:  200  best fitness:  0.372758   0.11567233797
# Epoch:  175  individuals:  200  best fitness:  0.372758   0.11157789341999999
#
# Calls 103146
# Epoch:  176  individuals:  200  best fitness:  0.372758   0.147670024
# Epoch:  176  individuals:  200  best fitness:  0.372758   0.11179011686
#
# Calls 103933
# Epoch:  177  individuals:  200  best fitness:  0.372768   0.1533466982
# Epoch:  177  individuals:  200  best fitness:  0.372758   0.11189012716
#
# Calls 104704
# Epoch:  178  individuals:  200  best fitness:  0.372769   0.1561336795
# Epoch:  178  individuals:  200  best fitness:  0.372758   0.11224558165000001
#
# Calls 105499
# Epoch:  179  individuals:  200  best fitness:  0.372769   0.1590000767
# Epoch:  179  individuals:  200  best fitness:  0.372758   0.11402345686
#
# Calls 106276
# Epoch:  180  individuals:  200  best fitness:  0.372769   0.1590000769
# Epoch:  180  individuals:  200  best fitness:  0.372758   0.11761456843
#
# Calls 107043
# Epoch:  181  individuals:  200  best fitness:  0.372769   0.1590013666
# Epoch:  181  individuals:  200  best fitness:  0.372758   0.1503344578
#
# Calls 107851
# Epoch:  182  individuals:  200  best fitness:  0.372769   0.1590023558
# Epoch:  182  individuals:  200  best fitness:  0.372758   0.1532223565
#
# Calls 108645
# Epoch:  183  individuals:  200  best fitness:  0.372769   0.1590122758
# Epoch:  183  individuals:  200  best fitness:  0.372758   0.15334567859999998
#
# Calls 109439
# Epoch:  184  individuals:  200  best fitness:  0.372769   0.1590333455
# Epoch:  184  individuals:  200  best fitness:  0.372758   0.15611348090000002
#
# Calls 110237
# Epoch:  185  individuals:  200  best fitness:  0.372769   0.15911135640000001
# Epoch:  185  individuals:  200  best fitness:  0.372758   0.1561345729
#
# Calls 111004
# Epoch:  186  individuals:  200  best fitness:  0.379777   0.1591356241
# Epoch:  186  individuals:  200  best fitness:  0.372758   0.156556703
#
# Calls 111795
# Epoch:  187  individuals:  200  best fitness:  0.379777   0.1618891676
# Epoch:  187  individuals:  200  best fitness:  0.372758   0.15900027449999998
#
# Calls 112601
# Epoch:  188  individuals:  200  best fitness:  0.379777   0.1619000601
# Epoch:  188  individuals:  200  best fitness:  0.372758   0.1590011659
#
# Calls 113370
# Epoch:  189  individuals:  200  best fitness:  0.379976   0.1621223432
# Epoch:  189  individuals:  200  best fitness:  0.372758   0.15900344730000002
#
# Calls 114169
# Epoch:  190  individuals:  200  best fitness:  0.379976   0.16490115789999998
# Epoch:  190  individuals:  200  best fitness:  0.372758   0.1590111448
#
# Calls 114921
# Epoch:  191  individuals:  200  best fitness:  0.379978   0.214001679
# Epoch:  191  individuals:  200  best fitness:  0.372758   0.15902337449999998
#
# Calls 115681
# Epoch:  192  individuals:  200  best fitness:  0.379978   0.218001735
# Epoch:  192  individuals:  200  best fitness:  0.372758   0.1591225941
#
# Calls 116412
# Epoch:  193  individuals:  200  best fitness:  0.379978   0.21801247399999998
# Epoch:  193  individuals:  200  best fitness:  0.372758   0.1591344787
#
# Calls 117078
# Epoch:  194  individuals:  200  best fitness:  0.379979   0.26900977
# Epoch:  194  individuals:  200  best fitness:  0.372758   0.1592346696
#
# Calls 117811
# Epoch:  195  individuals:  200  best fitness:  0.379979   0.32408760000000003
# Epoch:  195  individuals:  200  best fitness:  0.372758   0.15933345689999998
#
# Calls 118466
# Epoch:  196  individuals:  200  best fitness:  0.379979   0.3240879
# Epoch:  196  individuals:  200  best fitness:  0.372758   0.1618901666
#
# Calls 119116
# Epoch:  197  individuals:  200  best fitness:  0.379979   0.32409679999999996
# Epoch:  197  individuals:  200  best fitness:  0.372768   0.1619011325
#
# Calls 119804
# Epoch:  198  individuals:  200  best fitness:  0.379979   0.3240978
# Epoch:  198  individuals:  200  best fitness:  0.372768   0.1619222517
#
# Calls 120450
# Epoch:  199  individuals:  200  best fitness:  0.379979   0.26900979
# Epoch:  199  individuals:  200  best fitness:  0.372768   0.15934457059999999
#
# Calls 121069
# Epoch:  200  individuals:  200  best fitness:  0.379979   0.3240979
# Epoch:  200  individuals:  200  best fitness:  0.372768   0.1620011437
#
# Calls 121787
# Epoch:  201  individuals:  57  best fitness:  0.379979   0.053593466909
# Epoch:  201  individuals:  63  best fitness:  0.379979   0.054122349018999996
#
# Calls 121919
# Epoch:  202  individuals:  74  best fitness:  0.379979   0.054790233705999995
# Epoch:  202  individuals:  87  best fitness:  0.379979   0.055901237341
#
# Calls 122124
# Epoch:  203  individuals:  97  best fitness:  0.379979   0.055901223909
# Epoch:  203  individuals:  110  best fitness:  0.379979   0.10212570009
#
# Calls 122382
# Epoch:  204  individuals:  134  best fitness:  0.379979   0.056612244596
# Epoch:  204  individuals:  136  best fitness:  0.379979   0.10589000978999999
#
# Calls 122721
# Epoch:  205  individuals:  185  best fitness:  0.379979   0.056900224805
# Epoch:  205  individuals:  168  best fitness:  0.379979   0.10591112674
#
# Calls 123162
# Epoch:  206  individuals:  200  best fitness:  0.379979   0.10034678017
# Epoch:  206  individuals:  200  best fitness:  0.379979   0.10823356895000001
#
# Calls 123827
# Epoch:  207  individuals:  200  best fitness:  0.379979   0.10413456927
# Epoch:  207  individuals:  200  best fitness:  0.379979   0.15900008689999998
#
# Calls 124550
# Epoch:  208  individuals:  200  best fitness:  0.379979   0.10614566940999999
# Epoch:  208  individuals:  200  best fitness:  0.379979   0.214000979
#
# Calls 125258
# Epoch:  209  individuals:  200  best fitness:  0.379979   0.10790122755
# Epoch:  209  individuals:  200  best fitness:  0.379979   0.214001979
#
# Calls 125852
# Epoch:  210  individuals:  200  best fitness:  0.379979   0.10966911406
# Epoch:  210  individuals:  198  best fitness:  0.379979   0.218146939
#
# Calls 126447
# Epoch:  211  individuals:  200  best fitness:  0.379979   0.11011355571999999
# Epoch:  211  individuals:  200  best fitness:  0.379979   0.26900978
#
# Calls 127052
# Epoch:  212  individuals:  200  best fitness:  0.379979   0.11222456678
# Epoch:  212  individuals:  200  best fitness:  0.379979   0.26900978
#
# Calls 127687
# Epoch:  213  individuals:  200  best fitness:  0.379979   0.1562346895
# Epoch:  213  individuals:  200  best fitness:  0.379979   0.26900979
#
# Calls 128344
# Epoch:  214  individuals:  200  best fitness:  0.379979   0.15900018789999998
# Epoch:  214  individuals:  200  best fitness:  0.379979   0.26900979
#
# Calls 128941
# Epoch:  215  individuals:  200  best fitness:  0.379979   0.15902358960000001
# Epoch:  215  individuals:  200  best fitness:  0.379979   0.26901978000000004
#
# Calls 129651
# Epoch:  216  individuals:  200  best fitness:  0.379979   0.1620115049
# Epoch:  216  individuals:  200  best fitness:  0.379979   0.32409679999999996
#
# Calls 130282
# Epoch:  217  individuals:  200  best fitness:  0.379979   0.164901697
# Epoch:  217  individuals:  200  best fitness:  0.379979   0.32409679999999996
#
# Calls 130852
# Epoch:  218  individuals:  200  best fitness:  0.379979   0.1649266927
# Epoch:  218  individuals:  200  best fitness:  0.379979   0.161903565
#
# Calls 131392
# Epoch:  219  individuals:  200  best fitness:  0.38007799999999997   0.1618890099
# Epoch:  219  individuals:  200  best fitness:  0.379979   0.26900979
#
# Calls 132002
# Epoch:  220  individuals:  200  best fitness:  0.380079   0.26900959999999996
# Epoch:  220  individuals:  200  best fitness:  0.379979   0.3240978
#
# Calls 132616
# Epoch:  221  individuals:  200  best fitness:  0.380079   0.26901079
# Epoch:  221  individuals:  198  best fitness:  0.379979   0.3240879
#
# Calls 133100
# Epoch:  222  individuals:  200  best fitness:  0.380079   0.26901079
# Epoch:  222  individuals:  200  best fitness:  0.379979   0.3240978
#
# Calls 133724
# Epoch:  223  individuals:  200  best fitness:  0.380079   0.3240869
# Epoch:  223  individuals:  200  best fitness:  0.379979   0.3240978
#
# Calls 134314
# Epoch:  224  individuals:  200  best fitness:  0.380079   0.3240978
# Epoch:  224  individuals:  183  best fitness:  0.379979   0.3240979
#
# Calls 134755
# Epoch:  225  individuals:  200  best fitness:  0.380079   0.3240979
# Epoch:  225  individuals:  181  best fitness:  0.379979   0.3240979
#
# Calls 135235
# Epoch:  226  individuals:  200  best fitness:  0.380079   0.3240979
# Epoch:  226  individuals:  200  best fitness:  0.379979   0.11202234705000001
#
# Calls 135764
# Epoch:  227  individuals:  184  best fitness:  0.380079   0.3240979
# Epoch:  227  individuals:  200  best fitness:  0.379979   0.26900779
#
# Calls 136257
# Epoch:  228  individuals:  200  best fitness:  0.380079   0.3240979
# Epoch:  228  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 136773
# Epoch:  229  individuals:  200  best fitness:  0.380079   0.3240979
# Epoch:  229  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 137367
# Epoch:  230  individuals:  200  best fitness:  0.380079   0.32410789999999995
# Epoch:  230  individuals:  200  best fitness:  0.379979   0.26901979
#
# Calls 137917
# Epoch:  231  individuals:  188  best fitness:  0.380079   0.32410789999999995
# Epoch:  231  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 138420
# Epoch:  232  individuals:  189  best fitness:  0.380179   0.32410789999999995
# Epoch:  232  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 138903
# Epoch:  233  individuals:  200  best fitness:  0.380179   0.32410789999999995
# Epoch:  233  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 139516
# Epoch:  234  individuals:  200  best fitness:  0.380179   0.32410789999999995
# Epoch:  234  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 140090
# Epoch:  235  individuals:  200  best fitness:  0.380179   0.3241179
# Epoch:  235  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 140782
# Epoch:  236  individuals:  200  best fitness:  0.380179   0.3241179
# Epoch:  236  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 141310
# Epoch:  237  individuals:  200  best fitness:  0.380179   0.3241179
# Epoch:  237  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 141888
# Epoch:  238  individuals:  200  best fitness:  0.380179   0.3241179
# Epoch:  238  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 142436
# Epoch:  239  individuals:  200  best fitness:  0.380179   0.32420780000000005
# Epoch:  239  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 142950
# Epoch:  240  individuals:  200  best fitness:  0.380179   0.3241179
# Epoch:  240  individuals:  200  best fitness:  0.379979   0.3240979
#
# Calls 143615
# Epoch:  241  individuals:  64  best fitness:  0.380179   0.054123666907999995
# Epoch:  241  individuals:  74  best fitness:  0.380179   0.052893467948999996
#
# Calls 143782
# Epoch:  242  individuals:  79  best fitness:  0.380179   0.056180126828
# Epoch:  242  individuals:  101  best fitness:  0.380179   0.054467850028
#
# Calls 144007
# Epoch:  243  individuals:  96  best fitness:  0.380179   0.058112568898
# Epoch:  243  individuals:  141  best fitness:  0.380179   0.05666903592
#
# Calls 144304
# Epoch:  244  individuals:  125  best fitness:  0.380179   0.056233455901
# Epoch:  244  individuals:  179  best fitness:  0.380179   0.056724677905
#
# Calls 144700
# Epoch:  245  individuals:  178  best fitness:  0.380179   0.054811345913
# Epoch:  245  individuals:  200  best fitness:  0.380179   0.10024457907
#
# Calls 145225
# Epoch:  246  individuals:  200  best fitness:  0.380179   0.058590225616
# Epoch:  246  individuals:  200  best fitness:  0.380179   0.10601344784
#
# Calls 145883
# Epoch:  247  individuals:  200  best fitness:  0.380179   0.10211334454
# Epoch:  247  individuals:  200  best fitness:  0.380179   0.10793446691
#
# Calls 146439
# Epoch:  248  individuals:  200  best fitness:  0.380179   0.10589255674999999
# Epoch:  248  individuals:  200  best fitness:  0.380179   0.1080111249
#
# Calls 147021
# Epoch:  249  individuals:  200  best fitness:  0.380179   0.10791112251
# Epoch:  249  individuals:  200  best fitness:  0.380179   0.11022345561
#
# Calls 147691
# Epoch:  250  individuals:  200  best fitness:  0.380179   0.10990446783999999
# Epoch:  250  individuals:  200  best fitness:  0.380179   0.11355670124
#
# Calls 148308
# Epoch:  251  individuals:  200  best fitness:  0.380179   0.11201355685999999
# Epoch:  251  individuals:  200  best fitness:  0.380179   0.1561123554
#
# Calls 148902
# Epoch:  252  individuals:  200  best fitness:  0.380179   0.11362558934
# Epoch:  252  individuals:  200  best fitness:  0.380179   0.16201235879999998
#
# Calls 149561
# Epoch:  253  individuals:  200  best fitness:  0.380179   0.11557934455
# Epoch:  253  individuals:  200  best fitness:  0.380179   0.1676814933
#
# Calls 150120
# Epoch:  254  individuals:  200  best fitness:  0.380179   0.1592235815
# Epoch:  254  individuals:  200  best fitness:  0.380179   0.217890179
#
# Calls 150709
# Epoch:  255  individuals:  200  best fitness:  0.380179   0.10801566796
# Epoch:  255  individuals:  200  best fitness:  0.380179   0.26901179000000003
#
# Calls 151208
# Epoch:  256  individuals:  200  best fitness:  0.380179   0.202358041
# Epoch:  256  individuals:  200  best fitness:  0.380179   0.26901179000000003
#
# Calls 151733
# Epoch:  257  individuals:  186  best fitness:  0.380179   0.26900979
# Epoch:  257  individuals:  200  best fitness:  0.380179   0.3240979
#
# Calls 152210
# Epoch:  258  individuals:  185  best fitness:  0.380179   0.26901079
# Epoch:  258  individuals:  200  best fitness:  0.380179   0.3240979
#
# Calls 152673
# Epoch:  259  individuals:  200  best fitness:  0.380179   0.26901079
# Epoch:  259  individuals:  200  best fitness:  0.380179   0.26901179000000003
#
# Calls 153186
# Epoch:  260  individuals:  192  best fitness:  0.380179   0.26901179000000003
# Epoch:  260  individuals:  200  best fitness:  0.380179   0.3240979
#
# Calls 153691
# Epoch:  261  individuals:  176  best fitness:  0.380179   0.3240979
# Epoch:  261  individuals:  200  best fitness:  0.380179   0.32410789999999995
#
# Calls 154194
# Epoch:  262  individuals:  200  best fitness:  0.380179   0.214000979
# Epoch:  262  individuals:  200  best fitness:  0.380179   0.32410789999999995
#
# Calls 154748
# Epoch:  263  individuals:  200  best fitness:  0.380179   0.26902179
# Epoch:  263  individuals:  200  best fitness:  0.380179   0.32410789999999995
#
# Calls 155260
# Epoch:  264  individuals:  170  best fitness:  0.380179   0.32410789999999995
# Epoch:  264  individuals:  200  best fitness:  0.380179   0.32410789999999995
#
# Calls 155700
# Epoch:  265  individuals:  169  best fitness:  0.380179   0.32410789999999995
# Epoch:  265  individuals:  200  best fitness:  0.380179   0.32410789999999995
#
# Calls 156165
# Epoch:  266  individuals:  162  best fitness:  0.380179   0.32410789999999995
# Epoch:  266  individuals:  200  best fitness:  0.380179   0.32410789999999995
#
# Calls 156622
# Epoch:  267  individuals:  163  best fitness:  0.380179   0.32410789999999995
# Epoch:  267  individuals:  200  best fitness:  0.380179   0.32410789999999995
#
# Calls 157041
# Epoch:  268  individuals:  178  best fitness:  0.380179   0.26901178
# Epoch:  268  individuals:  200  best fitness:  0.380179   0.3241179
#
# Calls 157542
# Epoch:  269  individuals:  165  best fitness:  0.380179   0.32410789999999995
# Epoch:  269  individuals:  200  best fitness:  0.380179   0.1618890079
#
# Calls 157991
# Epoch:  270  individuals:  177  best fitness:  0.380179   0.26901179000000003
# Epoch:  270  individuals:  200  best fitness:  0.380179   0.32410789999999995
#
# Calls 158451
# Epoch:  271  individuals:  154  best fitness:  0.380179   0.3241178
# Epoch:  271  individuals:  200  best fitness:  0.380179   0.26902078999999995
#
# Calls 158844
# Epoch:  272  individuals:  167  best fitness:  0.380179   0.26901179000000003
# Epoch:  272  individuals:  200  best fitness:  0.380179   0.3241179
#
# Calls 159281
# Epoch:  273  individuals:  187  best fitness:  0.380179   0.12171168461
# Epoch:  273  individuals:  200  best fitness:  0.380179   0.32410789999999995
#
# Calls 159774
# Epoch:  274  individuals:  182  best fitness:  0.380179   0.26902078999999995
# Epoch:  274  individuals:  200  best fitness:  0.380179   0.3241179
#
# Calls 160240
# Epoch:  275  individuals:  200  best fitness:  0.380179   0.32410789999999995
# Epoch:  275  individuals:  200  best fitness:  0.380179   0.3241179
#
# Calls 160749
# Epoch:  276  individuals:  192  best fitness:  0.380179   0.2594584
# Epoch:  276  individuals:  200  best fitness:  0.380179   0.3241179
#
# Calls 161234
# Epoch:  277  individuals:  200  best fitness:  0.380179   0.32410789999999995
# Epoch:  277  individuals:  200  best fitness:  0.380179   0.3241179
#
# Calls 161752
# Epoch:  278  individuals:  195  best fitness:  0.380179   0.26901179000000003
# Epoch:  278  individuals:  200  best fitness:  0.380179   0.3241179
#
# Calls 162309
# Epoch:  279  individuals:  164  best fitness:  0.380179   0.3241179
# Epoch:  279  individuals:  200  best fitness:  0.380179   0.3241179
#
# Calls 162783
# Epoch:  280  individuals:  181  best fitness:  0.380179   0.26901179000000003
# Epoch:  280  individuals:  200  best fitness:  0.380179   0.3241179
#
# Calls 163391
# Epoch:  281  individuals:  67  best fitness:  0.380179   0.052801223688
# Epoch:  281  individuals:  72  best fitness:  0.380179   0.055401136883999995
#
# Calls 163563
# Epoch:  282  individuals:  90  best fitness:  0.380179   0.054350123787
# Epoch:  282  individuals:  102  best fitness:  0.380179   0.05546034572
#
# Calls 163810
# Epoch:  283  individuals:  125  best fitness:  0.380179   0.055680115692
# Epoch:  283  individuals:  147  best fitness:  0.380179   0.055689678917
#
# Calls 164166
# Epoch:  284  individuals:  181  best fitness:  0.380179   0.056291177918
# Epoch:  284  individuals:  200  best fitness:  0.380179   0.055934446805
#
# Calls 164687
# Epoch:  285  individuals:  200  best fitness:  0.380179   0.059003357798
# Epoch:  285  individuals:  200  best fitness:  0.380179   0.09845668141
#
# Calls 165369
# Epoch:  286  individuals:  200  best fitness:  0.380179   0.10401114262
# Epoch:  286  individuals:  200  best fitness:  0.380179   0.10411333608
#
# Calls 166116
# Epoch:  287  individuals:  200  best fitness:  0.380179   0.10601245576
# Epoch:  287  individuals:  200  best fitness:  0.380179   0.10633457810000001
#
# Calls 166864
# Epoch:  288  individuals:  200  best fitness:  0.380179   0.10811333349999999
# Epoch:  288  individuals:  200  best fitness:  0.380179   0.10822456808
#
# Calls 167518
# Epoch:  289  individuals:  200  best fitness:  0.380179   0.10822278905999999
# Epoch:  289  individuals:  200  best fitness:  0.380179   0.11001134484000001
#
# Calls 168175
# Epoch:  290  individuals:  200  best fitness:  0.380179   0.10968013494000001
# Epoch:  290  individuals:  200  best fitness:  0.380179   0.11002246697
#
# Calls 168884
# Epoch:  291  individuals:  200  best fitness:  0.380179   0.11179017005
# Epoch:  291  individuals:  200  best fitness:  0.380179   0.11161125697
#
# Calls 169555
# Epoch:  292  individuals:  200  best fitness:  0.380179   0.1137845903
# Epoch:  292  individuals:  200  best fitness:  0.380179   0.11557911412
#
# Calls 170222
# Epoch:  293  individuals:  200  best fitness:  0.380179   0.1533445805
# Epoch:  293  individuals:  200  best fitness:  0.380179   0.1618904195
#
# Calls 170833
# Epoch:  294  individuals:  200  best fitness:  0.380179   0.10824457473
# Epoch:  294  individuals:  200  best fitness:  0.380179   0.1618923266
#
# Calls 171345
# Epoch:  295  individuals:  200  best fitness:  0.380179   0.11211567853
# Epoch:  295  individuals:  192  best fitness:  0.380179   0.1621579128
#
# Calls 171848
# Epoch:  296  individuals:  200  best fitness:  0.380179   0.1561346216
# Epoch:  296  individuals:  200  best fitness:  0.380179   0.1504670239
#
# Calls 172422
# Epoch:  297  individuals:  200  best fitness:  0.380179   0.1590127073
# Epoch:  297  individuals:  200  best fitness:  0.380179   0.16777905759999998
#
# Calls 172974
# Epoch:  298  individuals:  200  best fitness:  0.380179   0.1618923397
# Epoch:  298  individuals:  199  best fitness:  0.380179   0.214001179
#
# Calls 173487
# Epoch:  299  individuals:  200  best fitness:  0.380179   0.16190129690000002
# ...
# Epoch:  7195  individuals:  197  best fitness:  0.399   0.27884
#
# Calls 3491472
# Epoch:  7196  individuals:  200  best fitness:  0.399   0.16190261409999998
# Epoch:  7196  individuals:  200  best fitness:  0.399   0.27884
#
# Calls 3492016
# Epoch:  7197  individuals:  200  best fitness:  0.399   0.1742236149
# Epoch:  7197  individuals:  187  best fitness:  0.399   0.27884
#
# Calls 3492486
# Epoch:  7198  individuals:  200  best fitness:  0.399   0.210380064
# Epoch:  7198  individuals:  190  best fitness:  0.399   0.27884
#
# Calls 3492989
# Epoch:  7199  individuals:  194  best fitness:  0.399   0.214367906
# Epoch:  7199  individuals:  188  best fitness:  0.399   0.2256738
#
# Calls 3493421
# Epoch:  7200  individuals:  198  best fitness:  0.399   0.22178399999999998
# Epoch:  7200  individuals:  184  best fitness:  0.399   0.27884579000000004
#
# Calls 3493912
# Epoch:  7201  individuals:  69  best fitness:  0.399   0.053901336816
# Epoch:  7201  individuals:  72  best fitness:  0.399   0.052781238971999996
#
# Calls 3494090
# Epoch:  7202  individuals:  89  best fitness:  0.399   0.054791250395999996
# Epoch:  7202  individuals:  101  best fitness:  0.399   0.053894670966
#
# Calls 3494332
# Epoch:  7203  individuals:  127  best fitness:  0.399   0.055113456791
# Epoch:  7203  individuals:  137  best fitness:  0.399   0.054790005303
#
# Calls 3494673
# Epoch:  7204  individuals:  188  best fitness:  0.399   0.055544568907
# Epoch:  7204  individuals:  193  best fitness:  0.399   0.055480457117
#
# Calls 3495170
# Epoch:  7205  individuals:  200  best fitness:  0.399   0.09656678897000001
# Epoch:  7205  individuals:  200  best fitness:  0.399   0.058922789018
#
# Calls 3495886
# Epoch:  7206  individuals:  200  best fitness:  0.399   0.10601224563
# Epoch:  7206  individuals:  200  best fitness:  0.399   0.10456779008
#
# Calls 3496641
# Epoch:  7207  individuals:  200  best fitness:  0.399   0.10966673
# Epoch:  7207  individuals:  200  best fitness:  0.399   0.10823567817
#
# Calls 3497316
# Epoch:  7208  individuals:  200  best fitness:  0.399   0.1096668557
# Epoch:  7208  individuals:  200  best fitness:  0.399   0.10970034583999999
#
# Calls 3497967
# Epoch:  7209  individuals:  200  best fitness:  0.399   0.10972379019999999
# Epoch:  7209  individuals:  200  best fitness:  0.399   0.11172258924
#
# Calls 3498638
# Epoch:  7210  individuals:  200  best fitness:  0.399   0.11001133356
# Epoch:  7210  individuals:  200  best fitness:  0.399   0.11572455574
#
# Calls 3499309
# Epoch:  7211  individuals:  200  best fitness:  0.399   0.11169223451
# Epoch:  7211  individuals:  200  best fitness:  0.399   0.1564453122
#
# Calls 3499986
# Epoch:  7212  individuals:  200  best fitness:  0.399   0.11345906238
# Epoch:  7212  individuals:  200  best fitness:  0.399   0.164779489
#
# Calls 3500628
# Epoch:  7213  individuals:  200  best fitness:  0.399   0.11346794146
# Epoch:  7213  individuals:  200  best fitness:  0.399   0.1676685
#
# Calls 3501219
# Epoch:  7214  individuals:  200  best fitness:  0.399   0.1504555683
# Epoch:  7214  individuals:  200  best fitness:  0.399   0.27883679
#
# Calls 3501800
# Epoch:  7215  individuals:  200  best fitness:  0.399   0.1533345641
# Epoch:  7215  individuals:  200  best fitness:  0.399   0.27884
#
# Calls 3502409
# Epoch:  7216  individuals:  200  best fitness:  0.399   0.1533457862
# Epoch:  7216  individuals:  197  best fitness:  0.399   0.27884
#
# Calls 3502901
# Epoch:  7217  individuals:  200  best fitness:  0.399   0.1618905116
# Epoch:  7217  individuals:  200  best fitness:  0.399   0.33637900000000004
#
# Calls 3503507
# Epoch:  7218  individuals:  200  best fitness:  0.399   0.16477944679999998
# Epoch:  7218  individuals:  200  best fitness:  0.399   0.3364
#
# Calls 3504043
# Epoch:  7219  individuals:  200  best fitness:  0.399   0.1677794558
# Epoch:  7219  individuals:  188  best fitness:  0.399   0.16766730000000002
#
# Calls 3504598
# Epoch:  7220  individuals:  200  best fitness:  0.399   0.210135007
# Epoch:  7220  individuals:  179  best fitness:  0.399   0.3364
#
# Calls 3505024
# Epoch:  7221  individuals:  198  best fitness:  0.399   0.221783789
# Epoch:  7221  individuals:  152  best fitness:  0.399   0.3364
#
# Calls 3505401
# Epoch:  7222  individuals:  171  best fitness:  0.399   0.229584058
# Epoch:  7222  individuals:  173  best fitness:  0.399   0.27884
#
# Calls 3505784
# Epoch:  7223  individuals:  183  best fitness:  0.399   0.27884
# Epoch:  7223  individuals:  175  best fitness:  0.399   0.27884
#
# Calls 3506204
# Epoch:  7224  individuals:  168  best fitness:  0.399   0.27884
# Epoch:  7224  individuals:  175  best fitness:  0.399   0.3364
#
# Calls 3506587
# Epoch:  7225  individuals:  176  best fitness:  0.399   0.2788479
# Epoch:  7225  individuals:  188  best fitness:  0.399   0.27884
#
# Calls 3507018
# Epoch:  7226  individuals:  177  best fitness:  0.399   0.3363789
# Epoch:  7226  individuals:  173  best fitness:  0.399   0.3364
#
# Calls 3507397
# Epoch:  7227  individuals:  184  best fitness:  0.399   0.33638
# Epoch:  7227  individuals:  185  best fitness:  0.399   0.3364
#
# Calls 3507828
# Epoch:  7228  individuals:  189  best fitness:  0.399   0.33638999999999997
# Epoch:  7228  individuals:  150  best fitness:  0.399   0.3364
#
# Calls 3508183
# Epoch:  7229  individuals:  200  best fitness:  0.399   0.33638999999999997
# Epoch:  7229  individuals:  161  best fitness:  0.399   0.3364
#
# Calls 3508614
# Epoch:  7230  individuals:  190  best fitness:  0.399   0.3364
# Epoch:  7230  individuals:  163  best fitness:  0.399   0.3364
#
# Calls 3508999
# Epoch:  7231  individuals:  197  best fitness:  0.399   0.3364
# Epoch:  7231  individuals:  174  best fitness:  0.399   0.3364
#
# Calls 3509417
# Epoch:  7232  individuals:  200  best fitness:  0.399   0.3364
# Epoch:  7232  individuals:  189  best fitness:  0.399   0.3364
#
# Calls 3509888
# Epoch:  7233  individuals:  200  best fitness:  0.399   0.3364
# Epoch:  7233  individuals:  192  best fitness:  0.399   0.3364
#
# Calls 3510350
# Epoch:  7234  individuals:  200  best fitness:  0.399   0.3364
# Epoch:  7234  individuals:  184  best fitness:  0.399   0.3364
#
# Calls 3510790
# Epoch:  7235  individuals:  186  best fitness:  0.399   0.3364
# Epoch:  7235  individuals:  178  best fitness:  0.399   0.3364
#
# Calls 3511177
# Epoch:  7236  individuals:  178  best fitness:  0.399   0.336489
# Epoch:  7236  individuals:  200  best fitness:  0.399   0.3364
#
# Calls 3511629
# Epoch:  7237  individuals:  180  best fitness:  0.399   0.3364
# Epoch:  7237  individuals:  200  best fitness:  0.399   0.3364
#
# Calls 3512124
# Epoch:  7238  individuals:  153  best fitness:  0.399   0.33649
# Epoch:  7238  individuals:  200  best fitness:  0.399   0.3364
#
# Calls 3512494
# Epoch:  7239  individuals:  145  best fitness:  0.399   0.3365
# Epoch:  7239  individuals:  200  best fitness:  0.399   0.3364
#
# Calls 3512933
# Epoch:  7240  individuals:  151  best fitness:  0.399   0.3364
# Epoch:  7240  individuals:  200  best fitness:  0.399   0.3364
#
# Calls 3513430
# Epoch:  7241  individuals:  65  best fitness:  0.399   0.053558279007
# Epoch:  7241  individuals:  64  best fitness:  0.399   0.053522348008
#
# Calls 3513583
# Epoch:  7242  individuals:  92  best fitness:  0.399   0.055366682826000005
# Epoch:  7242  individuals:  78  best fitness:  0.399   0.056516790016000004
#
# Calls 3513799
# Epoch:  7243  individuals:  130  best fitness:  0.399   0.055904556790000004
# Epoch:  7243  individuals:  84  best fitness:  0.399   0.09645678762
#
# Calls 3514064
# Epoch:  7244  individuals:  186  best fitness:  0.399   0.056144590182
# Epoch:  7244  individuals:  91  best fitness:  0.399   0.10402473539
#
# Calls 3514409
# Epoch:  7245  individuals:  200  best fitness:  0.399   0.058150557841000004
# Epoch:  7245  individuals:  116  best fitness:  0.399   0.10401245817999999
#
# Calls 3514921
# Epoch:  7246  individuals:  200  best fitness:  0.399   0.10411558239999999
# Epoch:  7246  individuals:  151  best fitness:  0.399   0.10412353117
#
# Calls 3515495
# Epoch:  7247  individuals:  200  best fitness:  0.399   0.10791358130999999
# Epoch:  7247  individuals:  175  best fitness:  0.399   0.10214694570999999
#
# Calls 3516075
# Epoch:  7248  individuals:  200  best fitness:  0.399   0.10978023783
# Epoch:  7248  individuals:  200  best fitness:  0.399   0.10411267008
#
# Calls 3516766
# Epoch:  7249  individuals:  200  best fitness:  0.399   0.11169002414000001
# Epoch:  7249  individuals:  200  best fitness:  0.399   0.10780459587999999
#
# Calls 3517476
# Epoch:  7250  individuals:  200  best fitness:  0.399   0.11561340372
# Epoch:  7250  individuals:  200  best fitness:  0.399   0.10966673
#
# Calls 3518128
# Epoch:  7251  individuals:  200  best fitness:  0.399   0.15323687290000002
# Epoch:  7251  individuals:  200  best fitness:  0.399   0.10978255708000001
#
# Calls 3518772
# Epoch:  7252  individuals:  200  best fitness:  0.399   0.1647895013
# Epoch:  7252  individuals:  200  best fitness:  0.399   0.10980021479999999
#
# Calls 3519447
# Epoch:  7253  individuals:  200  best fitness:  0.399   0.22178389999999998
# Epoch:  7253  individuals:  200  best fitness:  0.399   0.11180116017
#
# Calls 3520081
# Epoch:  7254  individuals:  200  best fitness:  0.399   0.278839
# Epoch:  7254  individuals:  200  best fitness:  0.399   0.10790147679999999
#
# Calls 3520653
# Epoch:  7255  individuals:  200  best fitness:  0.399   0.27885000000000004
# Epoch:  7255  individuals:  200  best fitness:  0.399   0.1118022486
#
# Calls 3521263
# Epoch:  7256  individuals:  193  best fitness:  0.399   0.3363789
# Epoch:  7256  individuals:  200  best fitness:  0.399   0.11378124725000001
#
# Calls 3521782
# Epoch:  7257  individuals:  179  best fitness:  0.399   0.336389
# Epoch:  7257  individuals:  200  best fitness:  0.399   0.11568960676000001
#
# Calls 3522329
# Epoch:  7258  individuals:  161  best fitness:  0.399   0.33638999999999997
# Epoch:  7258  individuals:  200  best fitness:  0.399   0.11791391505
#
# Calls 3522821
# Epoch:  7259  individuals:  144  best fitness:  0.399   0.3364
# Epoch:  7259  individuals:  200  best fitness:  0.399   0.11012473242
#
# Calls 3523249
# Epoch:  7260  individuals:  123  best fitness:  0.399   0.3364
# Epoch:  7260  individuals:  200  best fitness:  0.399   0.11791391505
#
# Calls 3523708
# Epoch:  7261  individuals:  123  best fitness:  0.399   0.3364
# Epoch:  7261  individuals:  200  best fitness:  0.399   0.15333890049999999
#
# Calls 3524193
# Epoch:  7262  individuals:  98  best fitness:  0.399   0.3364
# Epoch:  7262  individuals:  200  best fitness:  0.399   0.11234556238
#
# Calls 3524530
# Epoch:  7263  individuals:  109  best fitness:  0.399   0.336389
# Epoch:  7263  individuals:  200  best fitness:  0.399   0.15902248449999998
#
# Calls 3524991
# Epoch:  7264  individuals:  103  best fitness:  0.399   0.3364
# Epoch:  7264  individuals:  200  best fitness:  0.399   0.1619121571
#
# Calls 3525337
# Epoch:  7265  individuals:  107  best fitness:  0.399   0.27884
# Epoch:  7265  individuals:  200  best fitness:  0.399   0.11380567651
#
# Calls 3525687
# Epoch:  7266  individuals:  126  best fitness:  0.399   0.10966674
# Epoch:  7266  individuals:  200  best fitness:  0.399   0.15045569079999999
#
# Calls 3526134
# Epoch:  7267  individuals:  143  best fitness:  0.399   0.27884
# Epoch:  7267  individuals:  200  best fitness:  0.399   0.1648130602
#
# Calls 3526536
# Epoch:  7268  individuals:  143  best fitness:  0.399   0.11555746585
# Epoch:  7268  individuals:  200  best fitness:  0.399   0.1101338906
#
# Calls 3526975
# Epoch:  7269  individuals:  162  best fitness:  0.399   0.27884
# Epoch:  7269  individuals:  200  best fitness:  0.399   0.16490051690000002
#
# Calls 3527476
# Epoch:  7270  individuals:  191  best fitness:  0.399   0.27884
# Epoch:  7270  individuals:  200  best fitness:  0.399   0.1676898917
#
# Calls 3527976
# Epoch:  7271  individuals:  172  best fitness:  0.399   0.336389
# Epoch:  7271  individuals:  200  best fitness:  0.399   0.278839
#
# Calls 3528391
# Epoch:  7272  individuals:  178  best fitness:  0.399   0.33638999999999997
# Epoch:  7272  individuals:  192  best fitness:  0.399   0.27884
#
# Calls 3528817
# Epoch:  7273  individuals:  181  best fitness:  0.399   0.33638999999999997
# Epoch:  7273  individuals:  190  best fitness:  0.399   0.27884
#
# Calls 3529251
# Epoch:  7274  individuals:  177  best fitness:  0.399   0.3364
# Epoch:  7274  individuals:  200  best fitness:  0.399   0.27885000000000004
#
# Calls 3529704
# Epoch:  7275  individuals:  172  best fitness:  0.399   0.3364
# Epoch:  7275  individuals:  191  best fitness:  0.399   0.27884
#
# Calls 3530118
# Epoch:  7276  individuals:  191  best fitness:  0.399   0.33638999999999997
# Epoch:  7276  individuals:  158  best fitness:  0.399   0.3364
#
# Calls 3530507
# Epoch:  7277  individuals:  172  best fitness:  0.399   0.3364
# Epoch:  7277  individuals:  155  best fitness:  0.399   0.3364
#
# Calls 3530866
# Epoch:  7278  individuals:  173  best fitness:  0.399   0.3364
# Epoch:  7278  individuals:  150  best fitness:  0.399   0.3364
#
# Calls 3531226
# Epoch:  7279  individuals:  167  best fitness:  0.399   0.3364
# Epoch:  7279  individuals:  165  best fitness:  0.399   0.27884
#
# Calls 3531604
# Epoch:  7280  individuals:  177  best fitness:  0.399   0.27884
# Epoch:  7280  individuals:  164  best fitness:  0.399   0.27884
#
# Calls 3532052
# Epoch:  7281  individuals:  69  best fitness:  0.399   0.053579150037
# Epoch:  7281  individuals:  67  best fitness:  0.399   0.054336270363
#
# Calls 3532223
# Epoch:  7282  individuals:  93  best fitness:  0.399   0.054677906129
# Epoch:  7282  individuals:  72  best fitness:  0.399   0.056379011261
#
# Calls 3532421
# Epoch:  7283  individuals:  128  best fitness:  0.399   0.055579456017
# Epoch:  7283  individuals:  82  best fitness:  0.399   0.058035123454
#
# Calls 3532682
# Epoch:  7284  individuals:  188  best fitness:  0.399   0.055669029914
# Epoch:  7284  individuals:  117  best fitness:  0.399   0.055794446795
#
# Calls 3533081
# Epoch:  7285  individuals:  200  best fitness:  0.399   0.057168025811
# Epoch:  7285  individuals:  140  best fitness:  0.399   0.059026779008
#
# Calls 3533574
# Epoch:  7286  individuals:  200  best fitness:  0.399   0.060667035731
# Epoch:  7286  individuals:  179  best fitness:  0.399   0.09644667906
#
# Calls 3534154
# Epoch:  7287  individuals:  200  best fitness:  0.399   0.10423346673
# Epoch:  7287  individuals:  200  best fitness:  0.399   0.10402333591999999
#
# Calls 3534838
# Epoch:  7288  individuals:  200  best fitness:  0.399   0.10800067839000001
# Epoch:  7288  individuals:  200  best fitness:  0.399   0.10777912351999999
#
# Calls 3535554
# Epoch:  7289  individuals:  200  best fitness:  0.399   0.10968961792000001
# Epoch:  7289  individuals:  200  best fitness:  0.399   0.10823457938
#
# Calls 3536256
# Epoch:  7290  individuals:  200  best fitness:  0.399   0.11158936916000001
# Epoch:  7290  individuals:  200  best fitness:  0.399   0.10989011262
#
# Calls 3536916
# Epoch:  7291  individuals:  200  best fitness:  0.399   0.11367795778
# Epoch:  7291  individuals:  200  best fitness:  0.399   0.11166804523
#
# Calls 3537609
# Epoch:  7292  individuals:  200  best fitness:  0.399   0.1590024796
# Epoch:  7292  individuals:  200  best fitness:  0.399   0.11178114485
#
# Calls 3538277
# Epoch:  7293  individuals:  200  best fitness:  0.399   0.16766839
# Epoch:  7293  individuals:  200  best fitness:  0.399   0.11357912586
#
# Calls 3538934
# Epoch:  7294  individuals:  189  best fitness:  0.399   0.16779064489999998
# Epoch:  7294  individuals:  200  best fitness:  0.399   0.11615556797
#
# Calls 3539445
# Epoch:  7295  individuals:  200  best fitness:  0.399   0.22178459
# Epoch:  7295  individuals:  200  best fitness:  0.399   0.15035790059999998
#
# Calls 3540023
# Epoch:  7296  individuals:  200  best fitness:  0.399   0.221894789
# Epoch:  7296  individuals:  200  best fitness:  0.399   0.1592569016
#
# Calls 3540554
# Epoch:  7297  individuals:  200  best fitness:  0.399   0.278839
# Epoch:  7297  individuals:  200  best fitness:  0.399   0.11155697015999999
#
# Calls 3541080
# Epoch:  7298  individuals:  200  best fitness:  0.399   0.27884
# Epoch:  7298  individuals:  200  best fitness:  0.399   0.16213604950000002
#
# Calls 3541585
# Epoch:  7299  individuals:  200  best fitness:  0.399   0.27884
# Epoch:  7299  individuals:  200  best fitness:  0.399   0.1651255685
#
# Calls 3542117
